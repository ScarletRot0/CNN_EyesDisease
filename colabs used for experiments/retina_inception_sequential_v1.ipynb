# %% [markdown]
# **Nota:**
#
# *   Se debe tener encuenta que el google colab debe estar conectado en T4
# *   Se descarga la carpeta compartida (Dataset2)
# *   Se crea en el propio drive de la persona una carpeta con el mismo nombre (Dataset2)
# *   Se pega todo el contenido de la carpeta descargada

# %% [markdown]
# # **1. Se importa el Dataset**
#
#
#
# *   Se debe iniciar el entorno ejecución del dataset
# *   Para montar la unidad de Google Drive en el directorio /content/drive dentro del entorno de trabajo y acceder al dataset compartido en la carpeta "Dataset2".
# 1.   from google.colab import drive: Esta línea importa la funcionalidad necesaria para interactuar con Google Colab, que es el entorno de trabajo que estamos utilizando.
# 2.   drive.mount('/content/drive'): Esta línea monta la unidad de Google Drive en el directorio /content/drive dentro de nuestro entorno de trabajo. Ahora podemos acceder a los archivos almacenados en Google Drive como si estuvieramos en nuestro propio computador.

# %% [markdown]
# E

# %%
#Primer paso para correr la red neuronal
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **1. Instalación de tensorflow**
#
#
# En esta linea instalamos la biblioteca de TensorFlow en el entorno de trabajo que estamos utilizando, el sistema va a descargar e instalar la última versión de TensorFlow, junto con todas las dependencias necesarias. Esto nos permitirá utilizar las funcionalidades y herramientas para nuestro código de red neuronal.
# Una vez  instalado, podremos importar y utilizar sus módulos y funciones en nuestro código, permitiendo definir la arquitectura de nuestra red neuronal, entrenarla y evaluarla.

# %%
# !pip install tensorflow==2.15.1
# Out:
# Collecting tensorflow==2.15.1
#   Downloading tensorflow-2.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1) (18.1.1)
# Collecting ml-dtypes~=0.3.1 (from tensorflow==2.15.1)
#   Downloading ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1) (4.12.2)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow==2.15.1)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1) (1.64.1)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow==2.15.1)
#   Downloading tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow==2.15.1)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow==2.15.1)
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.15.1) (0.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.1) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.1) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.1) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.1) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.1) (3.0.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.1) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.1) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.1) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.1) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.1) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.1) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15.1) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.1) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.1) (3.2.2)
# Downloading tensorflow-2.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 3.2 MB/s eta 0:00:00
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 44.9 MB/s eta 0:00:00
# Downloading ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 57.9 MB/s eta 0:00:00
# Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 57.8 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 25.4 MB/s eta 0:00:00
# Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.4 MB/s eta 0:00:00
# Installing collected packages: wrapt, tensorflow-estimator, ml-dtypes, keras, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.16.0
#     Uninstalling wrapt-1.16.0:
#       Successfully uninstalled wrapt-1.16.0
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.0
#     Uninstalling ml-dtypes-0.4.0:
#       Successfully uninstalled ml-dtypes-0.4.0
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.1
#     Uninstalling keras-3.4.1:
#       Successfully uninstalled keras-3.4.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.0
#     Uninstalling tensorboard-2.17.0:
#       Successfully uninstalled tensorboard-2.17.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.17.0
#     Uninstalling tensorflow-2.17.0:
#       Successfully uninstalled tensorflow-2.17.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.15.1 which is incompatible.
# Successfully installed keras-2.15.0 ml-dtypes-0.3.2 tensorboard-2.15.2 tensorflow-2.15.1 tensorflow-estimator-2.15.0 wrapt-1.14.1

# %% [markdown]
# # **2. Se importan las Librerias**
#
#
#
# *   Este código en Python importa diversas bibliotecas esenciales para trabajar con datos, imágenes y modelos de aprendizaje profundo, lo cual es fundamental para el desarrollo de aplicaciones avanzadas. Las bibliotecas permiten interactuar con el sistema operativo, manejar el tiempo, y manipular datos en formato de tablas y matrices, lo que facilita el análisis de grandes conjuntos de datos. También se incluyen herramientas para el procesamiento de imágenes y para la creación y entrenamiento de redes neuronales profundas, esenciales en tareas como la clasificación y la detección de objetos. Además, se gestionan conjuntos de datos y modelos, y se configuran opciones para ignorar advertencias, asegurando un flujo de trabajo más limpio y eficiente. En conjunto, estas importaciones establecen un entorno robusto para el aprendizaje automático y la visión por computadora.

# %% [markdown]
# E

# %%
# import system libs
import os
import time
import shutil
import pathlib
import itertools

# import data handling tools
from datetime import datetime
import cv2
import datetime
import re
import numpy as np
import pandas as pd
import seaborn as sns
from tensorflow.keras.callbacks import CSVLogger
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True #Para procesar imagenes truncadas

# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint
# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %% [markdown]
# # **3. Generar rutas de archivos con etiquetas**
#
# Se genera rutas de archivos y sus etiquetas a partir de un directorio de datos, y luego divide esta información en conjuntos de entrenamiento, validación y prueba.
# * La función define_paths recorre las carpetas del directorio, creando listas de rutas de archivos y etiquetas basadas en los nombres de las carpetas.
# *La funcón define_df combina estas listas en un dataframe para facilitar su manejo.
# * La función split_data divide el dataframe en conjuntos de entrenamiento, validación y prueba de manera estratificada, asegurando una representación adecuada de las etiquetas en cada conjunto.

# %% [markdown]
# E

# %%
# Generar rutas de archivos con etiquetas
def define_paths(data_dir):
    filepaths = []  # Lista para almacenar las rutas de archivos
    labels = []  # Lista para almacenar las etiquetas de las imágenes

    folds = os.listdir(data_dir)  # Obtener una lista de todas las carpetas en el directorio de datos
    for fold in folds:  # Iterar sobre cada carpeta
        foldpath = os.path.join(data_dir, fold)  # Construir la ruta completa de la carpeta
        filelist = os.listdir(foldpath)  # Obtener una lista de todos los archivos en la carpeta
        for file in filelist:  # Iterar sobre cada archivo
            fpath = os.path.join(foldpath, file)  # Construir la ruta completa del archivo
            filepaths.append(fpath)  # Agregar la ruta del archivo a la lista
            labels.append(fold)  # Agregar la etiqueta de la carpeta a la lista

    return filepaths, labels  # Devolver las listas de rutas de archivos y etiquetas


# Concatenar rutas de archivos con etiquetas en un solo dataframe
def define_df(files, classes):
    Fseries = pd.Series(files, name= 'filepaths')  # Crear una serie de Pandas con las rutas de archivos
    Lseries = pd.Series(classes, name='labels')  # Crear una serie de Pandas con las etiquetas
    return pd.concat([Fseries, Lseries], axis= 1)  # Concatenar las series en un solo dataframe


# Dividir el dataframe en conjuntos de entrenamiento, validación y prueba
def split_data(data_dir):
    # Conjunto de entrenamiento
    files, classes = define_paths(data_dir)  # Obtener las rutas de archivos y etiquetas
    df = define_df(files, classes)  # Crear un dataframe a partir de las rutas y etiquetas
    strat = df['labels']  # Obtener las etiquetas del dataframe
    train_df, dummy_df = train_test_split(df,  train_size= 0.8, shuffle= True, random_state= 123, stratify= strat)  # Dividir el dataframe en conjuntos de entrenamiento y prueba

    # Conjuntos de validación y prueba
    strat = dummy_df['labels']  # Obtener las etiquetas del dataframe
    valid_df, test_df = train_test_split(dummy_df,  train_size= 0.5, shuffle= True, random_state= 123, stratify= strat)  # Dividir el dataframe en conjuntos de validación y prueba

    return train_df, valid_df, test_df  # Devolver los conjuntos de entrenamiento, validación y prueba

# %% [markdown]
# # **Preparar los datos de entrenamiento**
#
# Se prepara los datos de entrenamiento, validación y prueba para que puedan ser utilizados por el modelo de red neuronal, se crean generadores de datos de imágenes que convierten las imágenes en tensores y aplican algunas transformaciones, como el volteo horizontal, para aumentar la diversidad de los datos de entrenamiento.
# La función "create_gens()" toma los dataframes de entrenamiento, validación y prueba, y los convierte en generadores de datos de imágenes utilizando la biblioteca ImageDataGenerator de Keras. Estos generadores se encargan de cargar y procesar las imágenes a medida que se necesitan durante el entrenamiento y la evaluación del modelo. Además, se define un tamaño de lote personalizado para el conjunto de prueba sea mas eficiente.

# %% [markdown]
# E

# %%
def create_gens (train_df, valid_df, test_df, batch_size):
    '''
    Esta función toma los dataframes de entrenamiento, validación y prueba, y los adapta a un generador de datos de imágenes, ya que el modelo toma los datos de un generador de datos de imágenes.
    El generador de datos de imágenes convierte las imágenes en tensores.
    '''

    # Definir parámetros del modelo
    img_size = (224, 224)
    channels = 3 # o BGR o escala de grises
    color = 'rgb'
    img_shape = (img_size[0], img_size[1], channels)

    # Recomendado: utilizar una función personalizada para el tamaño del lote de prueba, de lo contrario podemos utilizar un tamaño de lote normal.
    ts_length = len(test_df)
    test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length%n == 0 and ts_length/n <= 80]))
    test_steps = ts_length // test_batch_size

    # Esta función se utilizará en el generador de datos de imágenes para la augmentación de datos, simplemente toma la imagen y la devuelve.
    def scalar(img):
        return img

    tr_gen = ImageDataGenerator(preprocessing_function= scalar, horizontal_flip= True)
    ts_gen = ImageDataGenerator(preprocessing_function= scalar)

    train_gen = tr_gen.flow_from_dataframe( train_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                        color_mode= color, shuffle= True, batch_size= batch_size)

    valid_gen = ts_gen.flow_from_dataframe( valid_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                        color_mode= color, shuffle= True, batch_size= batch_size)

    # Nota: utilizaremos un tamaño de lote de prueba personalizado y haremos shuffle= False
    test_gen = ts_gen.flow_from_dataframe( test_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                        color_mode= color, shuffle= False, batch_size= test_batch_size)

    return train_gen, valid_gen, test_gen

# %% [markdown]
# # **Visualización de imágenes de entrenamiento**
#
#
# * Esta función, show_images(), permite visualizar una muestra de las imágenes que se utilizarán para entrenar la red neuronal. Esto es útil para verificar que los datos de entrenamiento se han cargado correctamente y tener una idea visual de las clases o categorías que el modelo deberá aprender a distinguir.
# *   La función toma un generador de datos de imágenes como entrada, extrae una muestra de imágenes y etiquetas, y las muestra en una cuadrícula de 5x5. Cada imagen se escala al rango de 0 a 255 y se muestra junto con su etiqueta correspondiente. Esta función es valiosa durante el desarrollo y depuración del modelo de red neuronal, ya que permite al usuario inspeccionar visualmente una parte de los datos de entrenamiento y asegurarse de que el modelo tendrá suficiente información para aprender las características relevantes de las imágenes.

# %% [markdown]
# E

# %%
def show_images(gen):
    '''
    Esta función toma el generador de datos y muestra una muestra de las imágenes.
    '''

    # Devuelve las clases y las imágenes a mostrar
    g_dict = gen.class_indices        # Define un diccionario {'clase': índice}
    classes = list(g_dict.keys())     # Define una lista de las claves del diccionario (clases), nombres de clase: cadena
    images, labels = next(gen)        # Obtiene una muestra de tamaño batch del generador

    # Calcula el número de muestras a mostrar
    length = len(labels)        # Longitud de la muestra
    sample = min(length, 25)    # Verifica si la muestra es menor que 25 imágenes

    plt.figure(figsize= (20, 20))

    for i in range(sample):
        plt.subplot(5, 5, i + 1)
        image = images[i] / 255       # Escala los datos al rango (0 - 255)
        plt.imshow(image)
        index = np.argmax(labels[i])  # Obtiene el índice de la imagen
        class_name = classes[index]   # Obtiene la clase de la imagen
        plt.title(class_name, color= 'blue', fontsize= 12)
        plt.axis('off')
    plt.show()

# %% [markdown]
# # **Implementación de un Callback Personalizado**
# * Este código define un callback personalizado en Keras, denominado MyCallback, que se utiliza para monitorear y ajustar dinámicamente la tasa de aprendizaje durante el entrenamiento de un modelo. La función principal de este callback es mejorar la eficiencia del entrenamiento al ajustar la tasa de aprendizaje si no se observa mejora en la precisión o la pérdida del modelo después de un número específico de épocas.
# * El callback también registra métricas clave, como la precisión y la pérdida tanto del conjunto de entrenamiento como del conjunto de validación, y muestra información detallada en cada época, incluyendo el tiempo transcurrido. Si la precisión de entrenamiento o la pérdida de validación no mejoran después de varios ajustes, el entrenamiento se detiene, lo que ayuda a prevenir el sobreajuste y optimiza el tiempo de entrenamiento.

# %% [markdown]
# E

# %%
class MyCallback(keras.callbacks.Callback):
    def __init__(self, model, patience, stop_patience, threshold, factor, batches, epochs, ask_epoch=None):
        super(MyCallback, self).__init__()
        self.model = model
        self.patience = patience  # especifica cuántos epochs sin mejora antes de ajustar la tasa de aprendizaje
        self.stop_patience = stop_patience  # especifica cuántas veces se ajustará la tasa de aprendizaje sin mejora para detener el entrenamiento
        self.threshold = threshold  # especifica el umbral de precisión de entrenamiento cuando la tasa de aprendizaje se ajustará basada en la pérdida de validación
        self.factor = factor  # factor por el que se reducirá la tasa de aprendizaje
        self.batches = batches  # número de lotes de entrenamiento que se ejecutarán por epoch
        self.epochs = epochs #numero de epochs o epocas por entrenamiento

        # variables de callback
        self.count = 0  # cuenta cuántas veces se ha reducido la tasa de aprendizaje sin mejora
        self.stop_count = 0
        self.best_epoch = 1  # epoch con la pérdida más baja
        self.initial_lr = float(tf.keras.backend.get_value(model.optimizer.lr))  # obtiene la tasa de aprendizaje inicial y la guarda
        self.highest_tracc = 0.0  # establece la precisión de entrenamiento más alta en 0 inicialmente
        self.lowest_vloss = np.inf  # establece la pérdida de validación más baja en infinito inicialmente
        self.best_weights = self.model.get_weights()  # establece las mejores pesas como las pesas iniciales del modelo
        self.initial_weights = self.model.get_weights()  # guarda las pesas iniciales si se deben restaurar

    def on_train_begin(self, logs=None):
        msg = '{0:^8s}{1:^10s}{2:^9s}{3:^9s}{4:^9s}{5:^9s}{6:^9s}{7:^10s}{8:10s}{9:^8s}'.format('Epoch', 'Loss', 'Accuracy', 'V_loss', 'V_acc', 'LR', 'Next LR', 'Monitor', '% Improv', 'Duration')
        print(msg)
        self.start_time = time.time()

    def on_train_end(self, logs=None):
        stop_time = time.time()
        tr_duration = stop_time - self.start_time
        hours = tr_duration // 3600
        minutes = (tr_duration - (hours * 3600)) // 60
        seconds = tr_duration - ((hours * 3600) + (minutes * 60))

        msg = f'el tiempo de entrenamiento transcurrido fue {str(hours)} horas, {minutes:4.1f} minutos, {seconds:4.2f} segundos)'
        print(msg)

        # establece las pesas del modelo en las mejores pesas
        self.model.set_weights(self.best_weights)

    def on_train_batch_end(self, batch, logs=None):
        # obtiene la precisión y la pérdida del lote de entrenamiento
        acc = logs.get('accuracy') * 100
        loss = logs.get('loss')

        # imprime sobre la misma línea para mostrar el recuento de lotes de entrenamiento en ejecución
        msg = '{0:20s}procesando lote {1:} de {2:5s}-   precisión=  {3:5.3f}   -   pérdida: {4:8.5f}'.format(' ', str(batch), str(self.batches), acc, loss)
        print(msg, '\r', end= '')

    def on_epoch_begin(self, epoch, logs=None):
        self.ep_start = time.time()

    def on_epoch_end(self, epoch, logs=None):
        ep_end = time.time()
        duration = ep_end - self.ep_start

        lr = float(tf.keras.backend.get_value(self.model.optimizer.lr))  # obtiene la tasa de aprendizaje actual
        current_lr = lr
        acc = logs.get('accuracy')  # obtiene la precisión de entrenamiento
        v_acc = logs.get('val_accuracy')  # obtiene la precisión de validación
        loss = logs.get('loss')  # obtiene la pérdida de entrenamiento para este epoch
        v_loss = logs.get('val_loss')  # obtiene la pérdida de validación para este epoch

        if acc < self.threshold:  # si la precisión de entrenamiento es menor que el umbral, ajuste la tasa de aprendizaje basada en la precisión de entrenamiento
            monitor = 'accuracy'
            if epoch == 0:
                pimprov = 0.0
            else:
                pimprov = (acc - self.highest_tracc) * 100 / self.highest_tracc  # define la mejora del progreso del modelo

            if acc > self.highest_tracc:  # la precisión de entrenamiento mejoró en el epoch
                self.highest_tracc = acc  # establece la nueva precisión de entrenamiento más alta
                self.best_weights = self.model.get_weights()  # la precisión de entrenamiento mejoró, así que guarde las pesas
                self.count = 0  # restablece el contador a 0 ya que la precisión de entrenamiento mejoró
                self.stop_count = 0  # restablece el contador de paradas a 0
                if v_loss < self.lowest_vloss:
                    self.lowest_vloss = v_loss
                self.best_epoch = epoch + 1  # establece el valor del mejor epoch para este epoch

            else:
                # la precisión de entrenamiento no mejoró, verifique si esto ha sucedido durante el número de epochs de paciencia
                # si es así, ajuste la tasa de aprendizaje
                if self.count >= self.patience - 1:  # se debe ajustar la tasa de aprendizaje
                    lr = lr * self.factor  # ajuste la tasa de aprendizaje por factor
                    tf.keras.backend.set_value(self.model.optimizer.lr, lr)  # establezca la tasa de aprendizaje en el optimizador
                    self.count = 0  # restablece el contador a 0
                    self.stop_count = self.stop_count + 1  # cuenta el número de ajustes de tasa de aprendizaje consecutivos
                    self.count = 0  # restablece el contador a 0 otra vez
                    if v_loss < self.lowest_vloss:  # Se verifica si la pérdida de validación actual es menor que la pérdida de validación más baja registrada hasta ahora
                        self.lowest_vloss = v_loss  # Si es así, se actualiza el valor de la pérdida de validación más baja con el valor de la pérdida de validación actual
                else:
                    self.count = self.count + 1  # Se incrementa el contador de paciencia.

        else:  # Si la precisión de entrenamiento está por encima del umbral, se ajusta la tasa de aprendizaje en función de la pérdida de validación.
            monitor = 'val_loss'
            if epoch == 0:
                pimprov = 0.0
            else:
                pimprov = (self.lowest_vloss - v_loss) * 100 / self.lowest_vloss

            if v_loss < self.lowest_vloss:  # Se verifica si la pérdida de validación ha mejorado
                self.lowest_vloss = v_loss  #Se reemplaza la pérdida de validación más baja con la nueva pérdida de validación
                self.best_weights = self.model.get_weights()  # Se ajusta la tasa de aprendizaje
                self.count = 0  # restablecer el recuento desde que se mejoró loss validation
                self.stop_count = 0
                self.best_epoch = epoch + 1  # establecer el valor del mejor epoch para este epoch

            else:  # Si la pérdida de validación no ha mejorado
                if self.count >= self.patience - 1:  # Se necesita ajustar la tasa de aprendizaje
                    lr = lr * self.factor  # ajustar la tasa de aprendizaje
                    self.stop_count = self.stop_count + 1  # incrementar el contador de parada porque se ajustó lr
                    self.count = 0  # resetea el contador
                    tf.keras.backend.set_value(self.model.optimizer.lr, lr)  # establece la tasa de aprendizaje en el optimizador
                else:
                    self.count = self.count + 1  # Se incrementa el contador de paciencia

            if acc > self.highest_tracc:
                self.highest_tracc = acc

        msg = f'{str(epoch + 1):^3s}/{str(self.epochs):4s} {loss:^9.3f}{acc * 100:^9.3f}{v_loss:^9.5f}{v_acc * 100:^9.3f}{current_lr:^9.5f}{lr:^9.5f}{monitor:^11s}{pimprov:^10.2f}{duration:^8.2f}'
        print(msg)

        if self.stop_count > self.stop_patience - 1:  # Se verifica si se ha ajustado la tasa de aprendizaje stop_count veces sin mejora
            msg = f'El entrenamiento se ha detenido en el epoch {epoch + 1} después de {self.stop_patience} ajustes de la tasa de aprendizaje sin ninguna mejora.'
            print(msg)
            self.model.stop_training = True  # Se detiene el entrenamiento

# %% [markdown]
# # **Generación de Gráficos de Entrenamiento**
# Esta función en Python, llamada plot_training, toma una carpeta que contiene archivos CSV con el historial de entrenamiento de un modelo de aprendizaje profundo. Recorre cada archivo CSV en la carpeta, lee los datos de precisión y pérdida tanto para el conjunto de entrenamiento como de validación, y genera gráficos que muestran la evolución de estas métricas a lo largo de las épocas de entrenamiento.
# * La función crea dos subgráficos: uno para las pérdidas y otro para la precisión. En cada gráfico, se traza la evolución de las métricas de entrenamiento y validación. Además, se marca el punto correspondiente a la mejor pérdida de validación y a la mejor precisión de validación, mostrando el número de época en que se alcanzaron estos valores óptimos.
# * Finalmente, la función ajusta el diseño de los gráficos y guarda las imágenes generadas en la misma carpeta que los archivos CSV, utilizando el nombre del archivo CSV como base para el nombre del archivo de imagen. Esto facilita el seguimiento y análisis visual del proceso de entrenamiento del modelo.

# %%
def plot_training(csv_folder):
    '''
    Esta función toma todos los archivos CSV de una carpeta, traza el historial de precisión y pérdidas,
    y guarda las imágenes generadas en la misma carpeta.
    '''
    # Obtener todos los archivos .csv de la carpeta
    csv_files = [f for f in os.listdir(csv_folder) if f.endswith('.csv')]

    for csv_file in csv_files:
        # Leer el CSV
        df = pd.read_csv(os.path.join(csv_folder, csv_file))

        # Definir variables necesarias
        tr_acc = df['accuracy'] # Accuracy de entrenamiento
        tr_loss = df['loss'] # Pérdida de entrenamiento
        val_acc = df['val_accuracy'] # Accuracy de validación
        val_loss = df['val_loss'] # Pérdida de validación
        index_loss = np.argmin(val_loss) # Índice de la pérdida de validación más baja
        val_lowest = val_loss[index_loss] # Valor de la pérdida de validación más baja
        index_acc = np.argmax(val_acc) # Índice de la precisión de validación más alta
        acc_highest = val_acc[index_acc] # Valor de la precisión de validación más alta
        Epochs = [i+1 for i in range(len(tr_acc))] # Epochs
        loss_label = f'best epoch= {str(index_loss + 1)}' # Etiqueta para el mejor epoch de pérdida
        acc_label = f'best epoch= {str(index_acc + 1)}' # Etiqueta para el mejor epoch de precisión

        # Graficar historial de entrenamiento
        plt.figure(figsize= (20, 8)) # Tamaño de la figura
        plt.style.use('fivethirtyeight') # Estilo de la gráfica

        plt.subplot(1, 2, 1) # Subgráfico para pérdidas
        plt.plot(Epochs, tr_loss, 'r', label= 'Training loss') # Pérdida de entrenamiento
        plt.plot(Epochs, val_loss, 'g', label= 'Validation loss') # Pérdida de validación
        plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label) # Punto de el mejor epoch de pérdida
        plt.title('Training and Validation Loss') # Título del gráfico de pérdidas
        plt.xlabel('Epochs') # Etiqueta del eje x
        plt.ylabel('Loss') # Etiqueta del eje y
        plt.legend() # Leyenda

        plt.subplot(1, 2, 2) # Subgráfico para precisión
        plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy') # Precisión de entrenamiento
        plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy') # Precisión de validación
        plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label) # Punto de el mejor epoch de precisión
        plt.title('Training and Validation Accuracy') # Título del gráfico de precisión
        plt.xlabel('Epochs') # Etiqueta del eje x
        plt.ylabel('Accuracy') # Etiqueta del eje y
        plt.legend() # Leyenda

        plt.tight_layout() # Ajustar diseño

        # Guardar la imagen en la misma carpeta
        image_file = os.path.join(csv_folder, f"{os.path.splitext(csv_file)[0]}_plot.png")
        plt.savefig(image_file)
        plt.close()

# Ejemplo de uso:
# plot_training('/content/drive/MyDrive/Reportes dataset2 v1/inception/0.0001')
        plt.tight_layout # Ajustar diseño
        plt.show() # Mostrar gráficos

# %% [markdown]
# # **Visualización del entrenamiento de un modelo inception**
# La línea de código plot_training("/content/drive/MyDrive/Reportes dataset2 v1/inception/0.0001") llama a una función que genera gráficos para visualizar el proceso de entrenamiento de un modelo Inception, utilizando los resultados almacenados en archivos dentro de la carpeta especificada, que contiene los reportes de entrenamiento del modelo con un hiperparámetro de 0.0001; esta visualización ayuda a los investigadores y desarrolladores a entender cómo se comporta el modelo durante el entrenamiento, permitiendo detectar problemas como el sobreajuste o la subajuste, y requiere que la función plot_training esté definida correctamente en el entorno y que importe las bibliotecas necesarias para la creación de gráficos, así como que la carpeta contenga los archivos necesarios (como CSV o JSON) que contengan los datos de entrenamiento para que la función pueda ejecutarse sin errores.

# %%
plot_training("/content/drive/MyDrive/Reportes dataset2 v1/inception/0.0001")

# %% [markdown]
# # **Análisis de Estadísticas de Archivos CSV en una Carpeta**
#
# Este programa realiza un análisis detallado de múltiples archivos CSV almacenados en una carpeta específica. Extrae información crucial de cada archivo, como la precisión máxima de validación y la pérdida mínima de validación, junto con las épocas correspondientes en las que se alcanzaron estos valores. Además, organiza estos datos junto con el número de repetición (extraído del nombre del archivo) en un nuevo archivo CSV llamado resumen_resultados.csv. Este archivo resumen facilita la comparación y el análisis de los resultados obtenidos en diferentes ejecuciones, proporcionando una visión clara y organizada del rendimiento de los modelos analizados.

# %%
def calcular_estadisticas(carpeta):
    # Listar todos los archivos en la carpeta
    archivos = [f for f in os.listdir(carpeta) if f.endswith('.csv')]

    resultados = []

    # Expresión regular para extraer el número de repetición del nombre del archivo
    patron_repeticion = re.compile(r'rep_(\d+)')

    for archivo in archivos:
        ruta = os.path.join(carpeta, archivo)

        # Cargar el archivo CSV
        df = pd.read_csv(ruta)

        # Encontrar el val_accuracy más alto y su epoch
        max_val_acc = df['val_accuracy'].max()
        max_val_acc_epoch = df[df['val_accuracy'] == max_val_acc]['epoch'].values[0]

        # Encontrar el val_loss más bajo y su epoch
        min_val_loss = df['val_loss'].min()
        min_val_loss_epoch = df[df['val_loss'] == min_val_loss]['epoch'].values[0]

        # Extraer el número de repetición del nombre del archivo
        match = patron_repeticion.search(archivo)
        if match:
            repeticion = int(match.group(1))
        else:
            repeticion = None

        # Guardar los resultados en una lista
        resultados.append({
            'repeticion': repeticion,
            'max_val_accuracy': max_val_acc,
            'epoch_max_val_accuracy': max_val_acc_epoch,
            'min_val_loss': min_val_loss,
            'epoch_min_val_loss': min_val_loss_epoch
        })

    print(resultados)
    # Crear un DataFrame con los resultados
    results_df = pd.DataFrame(resultados)

    # Guardar los resultados en un nuevo archivo CSV
    results_df.to_csv(f'{carpeta}/resumen_resultados.csv', index=False)

    print(f"Resumen guardado en {carpeta}/resumen_resultados.csv")

# %% [markdown]
# # **Cálculo de estadísticas de entrenamiento**
# Estas líneas de código ejecutan la función calcular_estadisticas() con la ruta '/content/drive/MyDrive/Reportes dataset2 v1/inception/{learning rate}' como argumento. Esta función se encarga de analizar los archivos de registro de entrenamiento (logs) almacenados en la carpeta especificada y calcular estadísticas relevantes.
# Al ejecutar esta función, se procesarán todos los archivos de registro de entrenamiento (con extensión .csv) que se encuentren en la carpeta '/content/drive/MyDrive/Reportes dataset2 v1/inception/{learning rate}'. Para cada archivo, se extraerán métricas como la precisión y la pérdida de entrenamiento y validación, y se calcularán estadísticas como la mejor época (con menor pérdida de validación), la precisión y pérdida promedio, y la precisión y pérdida máximas.

# %%
#carpeta = '/content/drive/MyDrive/Reportes dataset2 v1/inception/0.001'
#calcular_estadisticas(carpeta)
carpeta = '/content/drive/MyDrive/Reportes dataset2 v1/inception/0.01'
calcular_estadisticas(carpeta)
carpeta = '/content/drive/MyDrive/Reportes dataset2 v1/inception/0.0001'
calcular_estadisticas(carpeta)
# Out:
# [{'repeticion': 1, 'max_val_accuracy': 0.7397590279579163, 'epoch_max_val_accuracy': 0, 'min_val_loss': 0.5884295105934143, 'epoch_min_val_loss': 5}, {'repeticion': 2, 'max_val_accuracy': 0.7397590279579163, 'epoch_max_val_accuracy': 0, 'min_val_loss': 0.5760899782180786, 'epoch_min_val_loss': 5}, {'repeticion': 3, 'max_val_accuracy': 0.7397590279579163, 'epoch_max_val_accuracy': 0, 'min_val_loss': 0.5808636546134949, 'epoch_min_val_loss': 4}, {'repeticion': 4, 'max_val_accuracy': 0.7397590279579163, 'epoch_max_val_accuracy': 0, 'min_val_loss': 0.5916837453842163, 'epoch_min_val_loss': 4}, {'repeticion': 5, 'max_val_accuracy': 0.742168664932251, 'epoch_max_val_accuracy': 5, 'min_val_loss': 0.5805520415306091, 'epoch_min_val_loss': 7}, {'repeticion': 10, 'max_val_accuracy': 0.7397590279579163, 'epoch_max_val_accuracy': 0, 'min_val_loss': 0.5822128057479858, 'epoch_min_val_loss': 4}, {'repeticion': 7, 'max_val_accuracy': 0.7397590279579163, 'epoch_max_val_accuracy': 1, 'min_val_loss': 0.5745806694030762, 'epoch_min_val_loss': 6}, {'repeticion': 8, 'max_val_accuracy': 0.7397590279579163, 'epoch_max_val_accuracy': 0, 'min_val_loss': 0.5747429132461548, 'epoch_min_val_loss': 7}, {'repeticion': 6, 'max_val_accuracy': 0.7397590279579163, 'epoch_max_val_accuracy': 0, 'min_val_loss': 0.5721386671066284, 'epoch_min_val_loss': 5}, {'repeticion': 9, 'max_val_accuracy': 0.7397590279579163, 'epoch_max_val_accuracy': 1, 'min_val_loss': 0.5763105750083923, 'epoch_min_val_loss': 4}]
# Resumen guardado en /content/drive/MyDrive/Reportes dataset2 v1/inception/0.01/resumen_resultados.csv
# [{'repeticion': 1, 'max_val_accuracy': 0.9373493790626526, 'epoch_max_val_accuracy': 9, 'min_val_loss': 3.05396032333374, 'epoch_min_val_loss': 17}, {'repeticion': 2, 'max_val_accuracy': 0.9397590160369872, 'epoch_max_val_accuracy': 11, 'min_val_loss': 2.936216115951538, 'epoch_min_val_loss': 20}, {'repeticion': 3, 'max_val_accuracy': 0.9469879269599916, 'epoch_max_val_accuracy': 17, 'min_val_loss': 1.4579957723617554, 'epoch_min_val_loss': 28}, {'repeticion': 4, 'max_val_accuracy': 0.9445782899856568, 'epoch_max_val_accuracy': 8, 'min_val_loss': 1.0044898986816406, 'epoch_min_val_loss': 39}, {'repeticion': 5, 'max_val_accuracy': 0.9469879269599916, 'epoch_max_val_accuracy': 7, 'min_val_loss': 1.1129004955291748, 'epoch_min_val_loss': 39}, {'repeticion': 7, 'max_val_accuracy': 0.9325301051139832, 'epoch_max_val_accuracy': 10, 'min_val_loss': 1.735668659210205, 'epoch_min_val_loss': 18}, {'repeticion': 6, 'max_val_accuracy': 0.9204819202423096, 'epoch_max_val_accuracy': 7, 'min_val_loss': 3.327483654022217, 'epoch_min_val_loss': 12}, {'repeticion': 8, 'max_val_accuracy': 0.942168653011322, 'epoch_max_val_accuracy': 16, 'min_val_loss': 1.207085371017456, 'epoch_min_val_loss': 39}, {'repeticion': 9, 'max_val_accuracy': 0.9397590160369872, 'epoch_max_val_accuracy': 13, 'min_val_loss': 0.7647372484207153, 'epoch_min_val_loss': 39}, {'repeticion': 10, 'max_val_accuracy': 0.9204819202423096, 'epoch_max_val_accuracy': 8, 'min_val_loss': 3.646149635314941, 'epoch_min_val_loss': 12}]
# Resumen guardado en /content/drive/MyDrive/Reportes dataset2 v1/inception/0.0001/resumen_resultados.csv

# %% [markdown]
# # **Análisis de Resultados de Experimentos de Aprendizaje Automático**
# Este programa está diseñado para analizar y comparar los resultados de varios experimentos de aprendizaje automático almacenados en archivos de texto. Organiza las carpetas por tasas de aprendizaje y extrae las métricas de precisión y pérdida de validación de cada repetición. Luego, identifica la repetición con el mejor rendimiento para cada tasa de aprendizaje y guarda un resumen de estos resultados en un archivo CSV, proporcionando una visión clara y concisa de las mejores configuraciones experimentales.

# %%
def encontrar_mejores_metricas(ruta_base):
    resultados = []

    for carpeta_lr in os.listdir(ruta_base):
        ruta_lr = os.path.join(ruta_base, carpeta_lr)

        if os.path.isdir(ruta_lr):
            mejor_val_acc = 0  # Inicializar mejor_val_acc
            mejor_val_loss = float('inf')  # Inicializar mejor_val_loss
            mejor_repeticion = None  # Inicializar mejor repeticion

            for archivo in os.listdir(ruta_lr):
                if archivo.endswith('.txt'):
                    ruta_archivo = os.path.join(ruta_lr, archivo)
                    repeticion = archivo.split('rep_')[-1].split('.txt')[0]

                    with open(ruta_archivo, 'r') as f:
                        lineas = f.readlines()

                    val_acc = 0
                    val_loss = float('inf')

                    for linea in lineas:
                        if 'Val Accuracy:' in linea:
                            val_acc = float(linea.split('Val Accuracy: ')[1].split()[0])
                        if 'Val Loss:' in linea:
                            val_loss = float(linea.split('Val Loss: ')[1].split()[0])

                    # Comparar y actualizar si encontramos una mejor repetición
                    if val_acc > mejor_val_acc or (val_acc == mejor_val_acc and val_loss < mejor_val_loss):
                        mejor_val_acc = val_acc
                        mejor_val_loss = val_loss
                        mejor_repeticion = int(repeticion)

            # Almacenar los resultados de la mejor repetición para este learning rate
            resultados.append({
                'learning_rate': float(carpeta_lr),
                'repeticion': mejor_repeticion,
                'mejor_val_accuracy': mejor_val_acc,
                'mejor_val_loss': mejor_val_loss
            })

    results_df = pd.DataFrame(resultados)
    # Guardar los resultados en un nuevo archivo CSV
    results_df.to_csv(f'{ruta_base}resumen_general.csv', index=False)

    print(f"Resumen guardado en {ruta_base}resumen_general.csv")

# %%
base_path = '/content/drive/MyDrive/Reportes dataset2 v1/inception/'
encontrar_mejores_metricas(base_path)
# Out:
# Resumen guardado en /content/drive/MyDrive/Reportes dataset2 v1/inception/resumen_general.csv

# %%
def calcular_varianza_general(ruta_base):
    resultados = []

    for carpeta_lr in os.listdir(ruta_base):
        ruta_lr = os.path.join(ruta_base, carpeta_lr)

        if os.path.isdir(ruta_lr):
            # Ruta del archivo resumen_resultados.csv
            archivo_resumen = os.path.join(ruta_lr, 'resumen_resultados.csv')

            if os.path.exists(archivo_resumen):
                # Leer el archivo CSV
                df = pd.read_csv(archivo_resumen)

                # Extraer las columnas necesarias: max_val_accuracy y min_val_loss
                val_accuracies = df['max_val_accuracy'].tolist()
                val_losses = df['min_val_loss'].tolist()

                # Calcular la varianza de val_loss y val_accuracy para este learning rate
                if val_losses and val_accuracies:
                    varianza_val_loss = np.var(val_losses)
                    varianza_val_accuracy = np.var(val_accuracies)

                    # Almacenar los resultados de la varianza
                    resultados.append({
                        'learning_rate': float(carpeta_lr),
                        'varianza_val_loss': varianza_val_loss,
                        'varianza_val_accuracy': varianza_val_accuracy
                    })

    # Convertir los resultados a un DataFrame
    results_df = pd.DataFrame(resultados)

    # Guardar los resultados en un archivo CSV
    results_df.to_csv(f'{ruta_base}/varianza_general.csv', index=False)

    print(f"Varianzas guardadas en {ruta_base}/varianza_general.csv")

# %%
# Especificar la carpeta base donde están las carpetas de los learning rates
ruta_base = "/content/drive/MyDrive/Reportes dataset2 v1/inception"
calcular_varianza_general(ruta_base)
# Out:
# Varianzas guardadas en /content/drive/MyDrive/Reportes dataset2 v1/inception/varianza_general.csv

# %% [markdown]
# # **Graficar Matriz de Confusión en Python**
# La función plot_confusion_matrix se utiliza para visualizar la matriz de confusión de un modelo de clasificación, lo que permite evaluar su rendimiento en términos de verdaderos positivos, falsos positivos, verdaderos negativos y falsos negativos. Al llamar a esta función, se puede graficar la matriz de confusión utilizando Matplotlib, donde se puede optar por normalizar los valores para facilitar la interpretación.
#
# La función toma como argumentos la matriz de confusión, las clases involucradas, y opciones para normalizar la matriz y personalizar el título y el mapa de colores. Al graficar, se muestran las etiquetas de las clases en los ejes, y se añaden los valores de cada celda de la matriz, con un color que indica la magnitud de los valores. Esto proporciona una representación visual clara del desempeño del modelo, permitiendo identificar áreas de mejora en la clasificación.

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Matriz de Confusión', cmap=plt.cm.Blues):
    '''
    Esta función grafica la matriz de confusión utilizando el método de sklearn.
    '''

    plt.figure(figsize=(10, 10)) # Tamaño de la figura
    plt.imshow(cm, interpolation='nearest', cmap=cmap) # Imagen de la matriz de confusión
    plt.title(title) # Título del gráfico
    plt.colorbar() # Barra de color para indicar la correspondencia entre los valores y los colores

    tick_marks = np.arange(len(classes)) # Marcas de los ejes
    plt.xticks(tick_marks, classes, rotation=45) # Etiquetas para el eje x con rotación de 45 grados
    plt.yticks(tick_marks, classes) # Etiquetas para el eje y

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] # Normalización de la matriz de confusión
        print('Matriz de Confusión Normalizada') # Mensaje indicando que la matriz está normalizada

    else:
        print('Matriz de Confusión sin Normalizar') # Mensaje indicando que la matriz no está normalizada

    print(cm) # Imprimir la matriz de confusión

    thresh = cm.max() / 2. # Umbral para el texto en las celdas de la matriz
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j], horizontalalignment='center', color='white' if cm[i, j] > thresh else 'black') # Añadir el valor de cada celda

    plt.tight_layout() # Ajustar el diseño de la figura
    plt.ylabel('Etiqueta Real') # Etiqueta del eje y
    plt.xlabel('Etiqueta Predicha') # Etiqueta del eje x

# %% [markdown]
# # **Preparación de los datos para el entrenamiento**
# Primero, se define la ruta del directorio donde se encuentran los datos, que en este caso es "/content/drive/MyDrive/dataset2". Se preparan los datos de entrada para el modelo de red neuronal, dividiendo los archivos en conjuntos de entrenamiento, validación y prueba, y creando generadores de datos de imágenes para una carga y procesamiento eficientes durante el entrenamiento. se intenta ejecutar dos funciones:
#
# split_data(): Esta función toma el directorio de datos y divide los archivos en tres conjuntos: entrenamiento, validación y prueba. Esto es importante para evaluar el rendimiento del modelo de manera más precisa.
# create_gens(): Esta función toma los dataframes de entrenamiento, validación y prueba, y crea generadores de datos de imágenes. Los generadores se encargan de cargar y procesar las imágenes a medida que se necesitan durante el entrenamiento y la evaluación del modelo. También se especifica el tamaño del lote (batch size) para cada conjunto.
# Si hay algún problema al ejecutar estas funciones, se imprime el mensaje "Invalid Input" y se detiene la ejecución.

# %% [markdown]
# E

# %%
data_dir="/content/drive/MyDrive/dataset2" #Para el dueño de la carpeta, data_dir="/content/drive/Shareddrives/dataset2" es para los que se les compartieron la carpeta

try:
    # Get splitted data
    train_df, valid_df, test_df = split_data(data_dir)

    # Get Generators
    batch_size = 16
    train_gen, valid_gen, test_gen = create_gens(train_df, valid_df, test_df, batch_size)

except:
    print('Invalid Input')
# Out:
# Found 3319 validated image filenames belonging to 2 classes.
# Found 415 validated image filenames belonging to 2 classes.
# Found 415 validated image filenames belonging to 2 classes.

# %% [markdown]
# # **Visualización de las imágenes de entrenamiento**
#
#
#
# Cuando se ejecuta esta línea, la función show_images() toma una muestra de las imágenes y etiquetas del generador de entrenamiento y las muestra en una cuadrícula de 5x4. Visualizando una pequeña parte de los datos de entrenamiento y tener una idea de las características y diversidad de las imágenes que el modelo deberá aprender a procesar.

# %% [markdown]
# E, tienen que salir 16 imagenes

# %%
show_images(train_gen)

# %% [markdown]
# # **Configuración y Entrenamiento de un Modelo de Aprendizaje Profundo**
# El código define una función llamada Solve que configura y entrena un modelo de aprendizaje profundo utilizando la arquitectura InceptionV3. Comienza estableciendo parámetros como el nombre del modelo, la tasa de aprendizaje, el tamaño del lote y el número de épocas. Luego, crea directorios para guardar los resultados y los pesos del modelo, y configura un logger para registrar el progreso del entrenamiento. La función también incluye la posibilidad de recuperar pesos de un modelo previamente entrenado.
#
# Se construye el modelo, compilando la tasa de aprendizaje especificada y se entrena utilizando generadores de datos. Durante el entrenamiento, se registran métricas de rendimiento y se guardan los mejores pesos. Finalmente, se evalúa el modelo en conjuntos de prueba y validación, y se registran los resultados en un archivo, junto con gráficos que muestran la precisión y la pérdida a lo largo de las épocas.

# %% [markdown]
# E

# %%
def Solve(nombre, learning, batch, rep, recuperar, epocas):
  full_name = nombre + "_learn_" + str(np.abs(np.log10(learning))) + "_batch_" + str(batch) + "_rep_" + str(rep)
  dest_folder = f"/content/drive/MyDrive/Reportes dataset2 v1/inception/{learning}/"
  temp_folder = f"/content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/{learning}/"
  file_name = dest_folder + full_name + ".txt"
  with open(file_name, 'a') as fid:
    fid.write("")
  # nombre del modelo h5
  file_model = dest_folder + full_name + ".h5"
  now = datetime.datetime.now()
  print(now.strftime("%d/%m/%Y %H:%M:%S"))
  print("Learning rate: " + str(learning) + "    batch size: " + str(batch) + "    rep: " + str(rep))
  print("\n")
  # logger
  nombre_logger = dest_folder + full_name + "_log.csv"
  csv_logger = CSVLogger(nombre_logger, append=True)

  # guardar los mejores pesos en cada epoch
  checkpoint_path = temp_folder + "temp_" + full_name + ".h5"
  checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                           verbose=1,
                                                           monitor='val_loss',
                                                           save_weights_only=True,
                                                           save_freq='epoch',
                                                           save_best_only=True)
  # Crear estructura del modelo
  img_size = (224, 224) # Tamaño de la imagen
  channels = 3 # Canales de la imagen (RGB)
  img_shape = (img_size[0], img_size[1], channels) # Forma de la imagen
  class_count = len(list(train_gen.class_indices.keys())) # Conteo de clases en la capa densa
  from tensorflow.keras.applications import InceptionV3

  base_model = tf.keras.applications.inception_v3.InceptionV3(
    include_top=False,
    weights='imagenet',
    input_shape=img_shape,
    pooling='max',
    classifier_activation='softmax')
  # Crear un nuevo modelo con el learning rate actual
  model = Sequential([
            base_model,
            BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001),
            Dense(256, kernel_regularizer=regularizers.l2(l=0.016), activity_regularizer=regularizers.l1(0.006),
                  bias_regularizer=regularizers.l1(0.006), activation='relu'),
            Dropout(rate=0.45, seed=123),
            Dense(class_count, activation='softmax')
  ])

  # Compilar el modelo con el learning rate actual y el batch size definido
  model.compile(Adamax(learning_rate=learning), loss='categorical_crossentropy', metrics=['accuracy'])
  patience = 3 # número de epochs  para esperar para ajustar lr si el valor monitoreado no mejora
  stop_patience = 5 # número de epochs para esperar antes de detener el entrenamiento si el valor monitoreado no mejora
  threshold = 0.9 # si la precisión del entrenamiento es < threshold, ajustar la precisión del monitor; de lo contrario, monitorear la pérdida de validación
  factor = 0.5 # factor para reducir lr
    # se carga el mejor modelo que exista en archivo, si se pide modo recuperacion
  if recuperar == 1:
    try:
      model.load_weights(checkpoint_path)
    except:
      print("No existe el archivo temporal " + checkpoint_path)
      print("Se cancela la ejecución")
      return

  # modo entrenamiento, se debe eliminar cualquier temporal
  if recuperar == 0:
    if os.path.isfile(checkpoint_path):
      os.remove(checkpoint_path)
    else:
      print("No existe previamente el archivo temporal " + checkpoint_path)
  callbacks = [MyCallback(model=model, patience=patience, stop_patience=stop_patience, threshold=threshold,
                    factor=factor, batches=batch, epochs=epocas), csv_logger, checkpoint_callback]
  history = model.fit(x=train_gen, epochs=epocas, verbose=0, callbacks=callbacks,
                            validation_data=valid_gen, validation_steps=None, shuffle=False)
  # guardar el modelo
  model.save(file_model)
  print("Modelo "+ full_name + " guardado con exito")
  print("\n")

  print("Testeando el modelo...")
  print("\n")
  test_lost, test_acc= model.evaluate(test_gen)
  print("\n")

  print("Validating...")
  print("\n")
  val_lost, val_acc= model.evaluate(valid_gen)
  print("\n")
  # escribir archivo de control
  now = datetime.datetime.now()
  dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
  with open(file_name, 'a') as fid:
    fid.write(dt_string + "\n")
    fid.write("Learning rate: " + str(learning) + "    batch size: " + str(batch) + "    rep: " + str(rep) + "\n")
    fid.write("Test Accuracy: " +  str(round(test_acc,3)) + "    Test Loss: " + str(round(test_lost,4)) + "    Val Accuracy: " + str(round(val_acc,3)) + "    Val Loss: " + str(round(val_lost,4)) + "\n")
    fid.write("\n")

  print("\n")
  print("Test Accuracy:\t", test_acc)
  print("Test Loss:    \t", test_lost)
  print("Val Accuracy: \t", val_acc)
  print("Val Loss:     \t", val_lost)
  print("\n")

  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.xlabel('Epoch')
  plt.legend(["Test accuracy","Val accuracy"], loc ="lower right")
  plt.grid()
  plt.show()

  now = datetime.datetime.now()
  print(now.strftime("%d/%m/%Y %H:%M:%S"))
  print("\n")
  print("==================================================================")
  print("\n")
  print("\n")

# %%
Solve(nombre = "inception_retina_v1_40", learning = 1e-4, batch = 16, rep = 6, recuperar = 0, epocas = 40)
# Out:
# 06/09/2024 02:49:50
# Learning rate: 0.0001    batch size: 16    rep: 6
#
#
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step
# No existe previamente el archivo temporal /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_6.h5
#  Epoch     Loss   Accuracy  V_loss    V_acc     LR     Next LR  Monitor  % Improv  Duration
#  1 /40     8.266   73.607   8.21645  77.831   0.00010  0.00010  accuracy     0.00   1191.91
#
# Epoch 1: val_loss improved from inf to 8.21645, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_6.h5
#  2 /40     7.066   86.562   6.88118  89.639   0.00010  0.00010  accuracy    17.60    43.66
#
# Epoch 2: val_loss improved from 8.21645 to 6.88118, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_6.h5
#  3 /40     6.414   88.641   6.19831  91.566   0.00010  0.00010  accuracy     2.40    43.68
#
# Epoch 3: val_loss improved from 6.88118 to 6.19831, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_6.h5
#  4 /40     5.902   91.112   5.71993  90.120   0.00010  0.00010  val_loss     7.72    44.30
#
# Epoch 4: val_loss improved from 6.19831 to 5.71993, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_6.h5
#  5 /40     5.490   92.437   5.36072  90.843   0.00010  0.00010  val_loss     6.28    45.42
#
# Epoch 5: val_loss improved from 5.71993 to 5.36072, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_6.h5
#  6 /40     5.139   93.130   5.04288  89.880   0.00010  0.00010  val_loss     5.93    43.98
#
# Epoch 6: val_loss improved from 5.36072 to 5.04288, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_6.h5
#  7 /40     4.810   94.125   4.70271  91.807   0.00010  0.00010  val_loss     6.75    44.86
#
# Epoch 7: val_loss improved from 5.04288 to 4.70271, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_6.h5
#  8 /40     4.497   95.571   4.41263  92.048   0.00010  0.00010  val_loss     6.17    43.99
#
# Epoch 8: val_loss improved from 4.70271 to 4.41263, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_6.h5
#  9 /40     4.211   95.782   4.18693  89.880   0.00010  0.00010  val_loss     5.11    43.12
#
# Epoch 9: val_loss improved from 4.41263 to 4.18693, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_6.h5
# 10 /40     3.926   96.806   4.01804  88.434   0.00010  0.00010  val_loss     4.03    43.60
#
# Epoch 10: val_loss improved from 4.18693 to 4.01804, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_6.h5
# 11 /40     3.665   96.806   3.84896  87.711   0.00010  0.00010  val_loss     4.21    43.70
#
# Epoch 11: val_loss improved from 4.01804 to 3.84896, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_6.h5
# 12 /40     3.439   98.162   3.61041  88.434   0.00010  0.00010  val_loss     6.20    43.05
#
# Epoch 12: val_loss improved from 3.84896 to 3.61041, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_6.h5
# 13 /40     3.271   97.770   3.32748  90.843   0.00010  0.00010  val_loss     7.84    45.20
#
# Epoch 13: val_loss improved from 3.61041 to 3.32748, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_6.h5
# 14 /40     3.105   98.132   4.37706  86.747   0.00010  0.00005  val_loss    -31.54   44.67
#
# Epoch 14: val_loss did not improve from 3.32748
# 15 /40     2.977   98.795   3.72284  88.193   0.00005  0.00002  val_loss    -11.88   42.62
#
# Epoch 15: val_loss did not improve from 3.32748
# 16 /40     2.900   99.277   3.55898  87.952   0.00002  0.00001  val_loss    -6.96    44.47
# El entrenamiento se ha detenido en el epoch 16 después de 3 ajustes de la tasa de aprendizaje sin ninguna mejora.
#
# Epoch 16: val_loss did not improve from 3.32748
# el tiempo de entrenamiento transcurrido fue 0.0 horas, 34.0 minutos, 18.24 segundos)
# Modelo inception_retina_v1_40_learn_4.0_batch_16_rep_6 guardado con exito
#
#
# Testeando el modelo...
#
#
# 83/83 [==============================] - 122s 1s/step - loss: 3.3378 - accuracy: 0.9181
#
#
# Validating...
#
#
# 26/26 [==============================] - 4s 153ms/step - loss: 3.3275 - accuracy: 0.9084
#
#
#
#
# Test Accuracy:	 0.9180722832679749
# Test Loss:    	 3.3377790451049805
# Val Accuracy: 	 0.908433735370636
# Val Loss:     	 3.3274848461151123
# 06/09/2024 03:26:27
#
#
# ==================================================================

# %%
Solve(nombre = "inception_retina_v1_40", learning = 1e-4, batch = 16, rep = 7, recuperar = 0, epocas = 40)
# Out:
# 06/09/2024 03:26:28
# Learning rate: 0.0001    batch size: 16    rep: 7
#
#
# No existe previamente el archivo temporal /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_7.h5
#  Epoch     Loss   Accuracy  V_loss    V_acc     LR     Next LR  Monitor  % Improv  Duration
#  1 /40     8.096   77.373   7.71973  82.169   0.00010  0.00010  accuracy     0.00    72.17
#
# Epoch 1: val_loss improved from inf to 7.71973, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_7.h5
#  2 /40     6.989   86.773   6.74864  87.952   0.00010  0.00010  accuracy    12.15    43.86
#
# Epoch 2: val_loss improved from 7.71973 to 6.74864, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_7.h5
#  3 /40     6.350   89.876   6.20370  85.542   0.00010  0.00010  accuracy     3.58    44.90
#
# Epoch 3: val_loss improved from 6.74864 to 6.20370, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_7.h5
#  4 /40     5.869   90.780   5.71844  90.602   0.00010  0.00010  val_loss     7.82    43.66
#
# Epoch 4: val_loss improved from 6.20370 to 5.71844, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_7.h5
#  5 /40     5.457   92.317   5.34221  90.602   0.00010  0.00010  val_loss     6.58    45.76
#
# Epoch 5: val_loss improved from 5.71844 to 5.34221, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_7.h5
#  6 /40     5.085   92.769   5.00081  88.193   0.00010  0.00010  val_loss     6.39    43.49
#
# Epoch 6: val_loss improved from 5.34221 to 5.00081, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_7.h5
#  7 /40     4.699   94.306   4.64300  88.193   0.00010  0.00010  val_loss     7.15    44.10
#
# Epoch 7: val_loss improved from 5.00081 to 4.64300, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_7.h5
#  8 /40     4.328   95.270   4.20665  92.771   0.00010  0.00010  val_loss     9.40    43.98
#
# Epoch 8: val_loss improved from 4.64300 to 4.20665, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_7.h5
#  9 /40     3.982   95.300   3.91285  91.566   0.00010  0.00010  val_loss     6.98    45.15
#
# Epoch 9: val_loss improved from 4.20665 to 3.91285, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_7.h5
# 10 /40     3.645   96.475   3.65863  88.675   0.00010  0.00010  val_loss     6.50    43.77
#
# Epoch 10: val_loss improved from 3.91285 to 3.65863, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_7.h5
# 11 /40     3.322   97.138   3.27907  93.253   0.00010  0.00010  val_loss    10.37    43.60
#
# Epoch 11: val_loss improved from 3.65863 to 3.27907, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_7.h5
# 12 /40     3.023   97.650   3.00168  92.771   0.00010  0.00010  val_loss     8.46    43.14
#
# Epoch 12: val_loss improved from 3.27907 to 3.00168, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_7.h5
# 13 /40     2.749   97.770   2.75557  90.843   0.00010  0.00010  val_loss     8.20    45.45
#
# Epoch 13: val_loss improved from 3.00168 to 2.75557, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_7.h5
# 14 /40     2.475   98.825   2.53865  90.361   0.00010  0.00010  val_loss     7.87    43.62
#
# Epoch 14: val_loss improved from 2.75557 to 2.53865, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_7.h5
# 15 /40     2.228   98.976   2.28197  91.325   0.00010  0.00010  val_loss    10.11    43.53
#
# Epoch 15: val_loss improved from 2.53865 to 2.28197, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_7.h5
# 16 /40     2.014   98.735   2.04520  92.289   0.00010  0.00010  val_loss    10.38    43.11
#
# Epoch 16: val_loss improved from 2.28197 to 2.04520, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_7.h5
# 17 /40     1.798   99.247   2.16399  85.301   0.00010  0.00005  val_loss    -5.81    44.92
#
# Epoch 17: val_loss did not improve from 2.04520
# 18 /40     1.660   99.187   2.01247  87.711   0.00005  0.00005  val_loss     1.60    43.90
#
# Epoch 18: val_loss improved from 2.04520 to 2.01247, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_7.h5
# 19 /40     1.579   99.367   1.73567  92.530   0.00005  0.00005  val_loss    13.75    43.09
#
# Epoch 19: val_loss improved from 2.01247 to 1.73567, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_7.h5
# 20 /40     1.503   99.608   1.80423  88.434   0.00005  0.00002  val_loss    -3.95    44.94
#
# Epoch 20: val_loss did not improve from 1.73567
# 21 /40     1.450   99.879   1.90077  87.711   0.00002  0.00001  val_loss    -9.51    43.18
#
# Epoch 21: val_loss did not improve from 1.73567
# 22 /40     1.426   99.699   1.74119  89.157   0.00001  0.00001  val_loss    -0.32    43.09
# El entrenamiento se ha detenido en el epoch 22 después de 3 ajustes de la tasa de aprendizaje sin ninguna mejora.
#
# Epoch 22: val_loss did not improve from 1.73567
# el tiempo de entrenamiento transcurrido fue 0.0 horas, 18.0 minutos, 19.30 segundos)
# Modelo inception_retina_v1_40_learn_4.0_batch_16_rep_7 guardado con exito
#
#
# Testeando el modelo...
#
#
# 83/83 [==============================] - 6s 69ms/step - loss: 1.7140 - accuracy: 0.9277
#
#
# Validating...
#
#
# 26/26 [==============================] - 4s 165ms/step - loss: 1.7357 - accuracy: 0.9253
#
#
#
#
# Test Accuracy:	 0.9277108311653137
# Test Loss:    	 1.713977336883545
# Val Accuracy: 	 0.925301194190979
# Val Loss:     	 1.7356714010238647
# 06/09/2024 03:45:08
#
#
# ==================================================================

# %%
Solve(nombre = "inception_retina_v1_40", learning = 1e-4, batch = 16, rep = 8, recuperar = 0, epocas = 40)
# Out:
# 06/09/2024 03:45:08
# Learning rate: 0.0001    batch size: 16    rep: 8
#
#
# No existe previamente el archivo temporal /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
#  Epoch     Loss   Accuracy  V_loss    V_acc     LR     Next LR  Monitor  % Improv  Duration
#  1 /40     7.948   78.427   7.58122  80.482   0.00010  0.00010  accuracy     0.00    72.39
#
# Epoch 1: val_loss improved from inf to 7.58122, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
#  2 /40     6.952   86.502   6.69352  90.602   0.00010  0.00010  accuracy    10.30    43.68
#
# Epoch 2: val_loss improved from 7.58122 to 6.69352, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
#  3 /40     6.356   89.063   6.12502  91.325   0.00010  0.00010  accuracy     2.96    43.70
#
# Epoch 3: val_loss improved from 6.69352 to 6.12502, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
#  4 /40     5.873   92.166   5.72046  91.566   0.00010  0.00010  val_loss     6.60    42.79
#
# Epoch 4: val_loss improved from 6.12502 to 5.72046, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
#  5 /40     5.456   92.407   5.30563  90.843   0.00010  0.00010  val_loss     7.25    44.77
#
# Epoch 5: val_loss improved from 5.72046 to 5.30563, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
#  6 /40     5.036   94.034   4.92408  89.639   0.00010  0.00010  val_loss     7.19    45.25
#
# Epoch 6: val_loss improved from 5.30563 to 4.92408, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
#  7 /40     4.653   94.486   4.52974  92.771   0.00010  0.00010  val_loss     8.01    43.83
#
# Epoch 7: val_loss improved from 4.92408 to 4.52974, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
#  8 /40     4.319   95.541   4.26595  92.048   0.00010  0.00010  val_loss     5.82    43.97
#
# Epoch 8: val_loss improved from 4.52974 to 4.26595, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
#  9 /40     4.024   96.113   3.97344  91.807   0.00010  0.00010  val_loss     6.86    44.61
#
# Epoch 9: val_loss improved from 4.26595 to 3.97344, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 10 /40     3.763   96.716   3.75199  91.566   0.00010  0.00010  val_loss     5.57    44.89
#
# Epoch 10: val_loss improved from 3.97344 to 3.75199, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 11 /40     3.539   97.138   3.60606  89.880   0.00010  0.00010  val_loss     3.89    42.90
#
# Epoch 11: val_loss improved from 3.75199 to 3.60606, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 12 /40     3.329   97.921   3.35751  93.012   0.00010  0.00010  val_loss     6.89    44.28
#
# Epoch 12: val_loss improved from 3.60606 to 3.35751, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 13 /40     3.139   98.403   3.20595  93.253   0.00010  0.00010  val_loss     4.51    43.88
#
# Epoch 13: val_loss improved from 3.35751 to 3.20595, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 14 /40     2.957   98.554   3.01744  92.289   0.00010  0.00010  val_loss     5.88    44.71
#
# Epoch 14: val_loss improved from 3.20595 to 3.01744, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 15 /40     2.773   98.976   2.82372  93.253   0.00010  0.00010  val_loss     6.42    43.19
#
# Epoch 15: val_loss improved from 3.01744 to 2.82372, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 16 /40     2.594   98.704   2.63599  91.566   0.00010  0.00010  val_loss     6.65    44.48
#
# Epoch 16: val_loss improved from 2.82372 to 2.63599, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 17 /40     2.393   98.825   2.42325  94.217   0.00010  0.00010  val_loss     8.07    43.52
#
# Epoch 17: val_loss improved from 2.63599 to 2.42325, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 18 /40     2.205   99.367   2.25874  93.253   0.00010  0.00010  val_loss     6.79    43.56
#
# Epoch 18: val_loss improved from 2.42325 to 2.25874, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 19 /40     2.026   99.247   2.10000  91.807   0.00010  0.00010  val_loss     7.03    43.29
#
# Epoch 19: val_loss improved from 2.25874 to 2.10000, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 20 /40     1.854   99.518   1.96962  91.566   0.00010  0.00010  val_loss     6.21    44.06
#
# Epoch 20: val_loss improved from 2.10000 to 1.96962, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 21 /40     1.714   99.367   1.80448  93.976   0.00010  0.00010  val_loss     8.38    43.78
#
# Epoch 21: val_loss improved from 1.96962 to 1.80448, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 22 /40     1.582   99.428   1.68925  93.494   0.00010  0.00010  val_loss     6.39    43.59
#
# Epoch 22: val_loss improved from 1.80448 to 1.68925, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 23 /40     1.471   99.397   1.63846  91.807   0.00010  0.00010  val_loss     3.01    43.30
#
# Epoch 23: val_loss improved from 1.68925 to 1.63846, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 24 /40     1.376   99.638   1.54135  93.494   0.00010  0.00010  val_loss     5.93    44.02
#
# Epoch 24: val_loss improved from 1.63846 to 1.54135, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 25 /40     1.296   99.638   1.46783  92.289   0.00010  0.00010  val_loss     4.77    43.38
#
# Epoch 25: val_loss improved from 1.54135 to 1.46783, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 26 /40     1.235   99.247   1.54175  86.988   0.00010  0.00005  val_loss    -5.04    44.53
#
# Epoch 26: val_loss did not improve from 1.46783
# 27 /40     1.186   99.608   1.42511  90.120   0.00005  0.00005  val_loss     2.91    43.04
#
# Epoch 27: val_loss improved from 1.46783 to 1.42511, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 28 /40     1.152   99.638   1.35244  91.566   0.00005  0.00005  val_loss     5.10    43.26
#
# Epoch 28: val_loss improved from 1.42511 to 1.35244, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 29 /40     1.116   99.879   1.41405  90.120   0.00005  0.00002  val_loss    -4.56    44.92
#
# Epoch 29: val_loss did not improve from 1.35244
# 30 /40     1.091   99.849   1.33939  90.843   0.00002  0.00002  val_loss     0.96    43.10
#
# Epoch 30: val_loss improved from 1.35244 to 1.33939, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 31 /40     1.074   99.879   1.28932  92.771   0.00002  0.00002  val_loss     3.74    44.17
#
# Epoch 31: val_loss improved from 1.33939 to 1.28932, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 32 /40     1.050   99.849   1.30270  91.084   0.00002  0.00001  val_loss    -1.04    43.14
#
# Epoch 32: val_loss did not improve from 1.28932
# 33 /40     1.031   99.879   1.25132  93.253   0.00001  0.00001  val_loss     2.95    44.09
#
# Epoch 33: val_loss improved from 1.28932 to 1.25132, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 34 /40     1.019   99.940   1.24414  93.012   0.00001  0.00001  val_loss     0.57    43.12
#
# Epoch 34: val_loss improved from 1.25132 to 1.24414, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 35 /40     1.006   99.910   1.24417  92.771   0.00001  0.00001  val_loss    -0.00    43.41
#
# Epoch 35: val_loss did not improve from 1.24414
# 36 /40     0.997   99.910   1.24217  92.289   0.00001  0.00001  val_loss     0.16    44.67
#
# Epoch 36: val_loss improved from 1.24414 to 1.24217, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 37 /40     0.988   100.000  1.23226  92.771   0.00001  0.00001  val_loss     0.80    42.95
#
# Epoch 37: val_loss improved from 1.24217 to 1.23226, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 38 /40     0.982   99.910   1.21472  93.012   0.00001  0.00001  val_loss     1.42    44.27
#
# Epoch 38: val_loss improved from 1.23226 to 1.21472, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 39 /40     0.976   99.879   1.21034  92.530   0.00001  0.00001  val_loss     0.36    43.50
#
# Epoch 39: val_loss improved from 1.21472 to 1.21034, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# 40 /40     0.969   99.940   1.20709  93.012   0.00001  0.00001  val_loss     0.27    44.51
#
# Epoch 40: val_loss improved from 1.21034 to 1.20709, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_8.h5
# el tiempo de entrenamiento transcurrido fue 0.0 horas, 36.0 minutos, 50.48 segundos)
# Modelo inception_retina_v1_40_learn_4.0_batch_16_rep_8 guardado con exito
#
#
# Testeando el modelo...
#
#
# 83/83 [==============================] - 6s 68ms/step - loss: 1.1961 - accuracy: 0.9301
#
#
# Validating...
#
#
# 26/26 [==============================] - 5s 180ms/step - loss: 1.2071 - accuracy: 0.9301
#
#
#
#
# Test Accuracy:	 0.9301204681396484
# Test Loss:    	 1.1961222887039185
# Val Accuracy: 	 0.9301204681396484
# Val Loss:     	 1.2070852518081665
# 06/09/2024 04:22:16
#
#
# ==================================================================

# %%
Solve(nombre = "inception_retina_v1_40", learning = 1e-4, batch = 16, rep = 9, recuperar = 0, epocas = 40)
# Out:
# 06/09/2024 04:22:17
# Learning rate: 0.0001    batch size: 16    rep: 9
#
#
# No existe previamente el archivo temporal /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
#  Epoch     Loss   Accuracy  V_loss    V_acc     LR     Next LR  Monitor  % Improv  Duration
#  1 /40     8.132   74.782   7.89040  83.614   0.00010  0.00010  accuracy     0.00    72.60
#
# Epoch 1: val_loss improved from inf to 7.89040, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
#  2 /40     7.001   86.291   6.72513  87.470   0.00010  0.00010  accuracy    15.39    43.85
#
# Epoch 2: val_loss improved from 7.89040 to 6.72513, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
#  3 /40     6.351   89.033   6.08404  88.193   0.00010  0.00010  accuracy     3.18    43.96
#
# Epoch 3: val_loss improved from 6.72513 to 6.08404, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
#  4 /40     5.819   90.178   5.62582  89.157   0.00010  0.00010  val_loss     7.53    43.82
#
# Epoch 4: val_loss improved from 6.08404 to 5.62582, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
#  5 /40     5.358   92.347   5.34509  85.542   0.00010  0.00010  val_loss     4.99    43.25
#
# Epoch 5: val_loss improved from 5.62582 to 5.34509, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
#  6 /40     4.953   93.522   4.81658  92.289   0.00010  0.00010  val_loss     9.89    44.85
#
# Epoch 6: val_loss improved from 5.34509 to 4.81658, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
#  7 /40     4.604   94.456   4.50876  91.325   0.00010  0.00010  val_loss     6.39    43.18
#
# Epoch 7: val_loss improved from 4.81658 to 4.50876, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
#  8 /40     4.286   95.029   4.21102  91.807   0.00010  0.00010  val_loss     6.60    43.38
#
# Epoch 8: val_loss improved from 4.50876 to 4.21102, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
#  9 /40     3.995   95.782   3.93180  93.012   0.00010  0.00010  val_loss     6.63    43.96
#
# Epoch 9: val_loss improved from 4.21102 to 3.93180, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 10 /40     3.722   96.234   3.68909  93.253   0.00010  0.00010  val_loss     6.17    44.90
#
# Epoch 10: val_loss improved from 3.93180 to 3.68909, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 11 /40     3.469   97.288   3.44859  92.289   0.00010  0.00010  val_loss     6.52    43.40
#
# Epoch 11: val_loss improved from 3.68909 to 3.44859, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 12 /40     3.236   98.042   3.24192  92.289   0.00010  0.00010  val_loss     5.99    45.22
#
# Epoch 12: val_loss improved from 3.44859 to 3.24192, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 13 /40     3.052   97.499   3.06454  92.771   0.00010  0.00010  val_loss     5.47    42.63
#
# Epoch 13: val_loss improved from 3.24192 to 3.06454, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 14 /40     2.872   97.831   2.90907  93.976   0.00010  0.00010  val_loss     5.07    43.52
#
# Epoch 14: val_loss improved from 3.06454 to 2.90907, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 15 /40     2.712   98.463   2.75450  93.976   0.00010  0.00010  val_loss     5.31    44.27
#
# Epoch 15: val_loss improved from 2.90907 to 2.75450, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 16 /40     2.571   98.704   2.64215  92.771   0.00010  0.00010  val_loss     4.08    42.93
#
# Epoch 16: val_loss improved from 2.75450 to 2.64215, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 17 /40     2.438   98.915   2.49551  93.494   0.00010  0.00010  val_loss     5.55    43.90
#
# Epoch 17: val_loss improved from 2.64215 to 2.49551, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 18 /40     2.326   98.885   2.37655  93.735   0.00010  0.00010  val_loss     4.77    45.19
#
# Epoch 18: val_loss improved from 2.49551 to 2.37655, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 19 /40     2.212   99.006   2.26891  93.735   0.00010  0.00010  val_loss     4.53    43.13
#
# Epoch 19: val_loss improved from 2.37655 to 2.26891, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 20 /40     2.097   99.217   2.16726  93.253   0.00010  0.00010  val_loss     4.48    44.04
#
# Epoch 20: val_loss improved from 2.26891 to 2.16726, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 21 /40     1.982   99.397   2.04364  93.976   0.00010  0.00010  val_loss     5.70    42.82
#
# Epoch 21: val_loss improved from 2.16726 to 2.04364, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 22 /40     1.872   99.367   1.96776  93.494   0.00010  0.00010  val_loss     3.71    44.66
#
# Epoch 22: val_loss improved from 2.04364 to 1.96776, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 23 /40     1.765   99.337   1.88228  92.048   0.00010  0.00010  val_loss     4.34    43.00
#
# Epoch 23: val_loss improved from 1.96776 to 1.88228, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 24 /40     1.662   99.488   1.74984  93.494   0.00010  0.00010  val_loss     7.04    42.80
#
# Epoch 24: val_loss improved from 1.88228 to 1.74984, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 25 /40     1.561   99.638   1.67756  92.530   0.00010  0.00010  val_loss     4.13    45.70
#
# Epoch 25: val_loss improved from 1.74984 to 1.67756, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 26 /40     1.472   99.397   1.57961  93.494   0.00010  0.00010  val_loss     5.84    44.08
#
# Epoch 26: val_loss improved from 1.67756 to 1.57961, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 27 /40     1.381   99.337   1.47786  93.735   0.00010  0.00010  val_loss     6.44    43.25
#
# Epoch 27: val_loss improved from 1.57961 to 1.47786, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 28 /40     1.289   99.669   1.41133  93.253   0.00010  0.00010  val_loss     4.50    42.73
#
# Epoch 28: val_loss improved from 1.47786 to 1.41133, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 29 /40     1.227   99.428   1.34503  93.253   0.00010  0.00010  val_loss     4.70    43.03
#
# Epoch 29: val_loss improved from 1.41133 to 1.34503, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 30 /40     1.159   99.849   1.27836  93.735   0.00010  0.00010  val_loss     4.96    44.68
#
# Epoch 30: val_loss improved from 1.34503 to 1.27836, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 31 /40     1.103   99.669   1.24830  92.289   0.00010  0.00010  val_loss     2.35    46.11
#
# Epoch 31: val_loss improved from 1.27836 to 1.24830, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 32 /40     1.049   99.608   1.18952  92.530   0.00010  0.00010  val_loss     4.71    43.24
#
# Epoch 32: val_loss improved from 1.24830 to 1.18952, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 33 /40     0.992   99.970   1.12659  93.735   0.00010  0.00010  val_loss     5.29    43.54
#
# Epoch 33: val_loss improved from 1.18952 to 1.12659, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 34 /40     0.936   99.879   1.11045  93.976   0.00010  0.00010  val_loss     1.43    42.86
#
# Epoch 34: val_loss improved from 1.12659 to 1.11045, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 35 /40     0.874   99.940   1.02252  93.494   0.00010  0.00010  val_loss     7.92    45.20
#
# Epoch 35: val_loss improved from 1.11045 to 1.02252, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 36 /40     0.815   99.789   0.96379  93.976   0.00010  0.00010  val_loss     5.74    43.69
#
# Epoch 36: val_loss improved from 1.02252 to 0.96379, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 37 /40     0.751   99.819   0.92283  92.771   0.00010  0.00010  val_loss     4.25    43.69
#
# Epoch 37: val_loss improved from 0.96379 to 0.92283, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 38 /40     0.695   99.699   0.83894  93.735   0.00010  0.00010  val_loss     9.09    42.90
#
# Epoch 38: val_loss improved from 0.92283 to 0.83894, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 39 /40     0.651   99.548   0.78947  93.012   0.00010  0.00010  val_loss     5.90    44.02
#
# Epoch 39: val_loss improved from 0.83894 to 0.78947, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# 40 /40     0.601   99.910   0.76474  93.253   0.00010  0.00010  val_loss     3.13    43.91
#
# Epoch 40: val_loss improved from 0.78947 to 0.76474, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_9.h5
# el tiempo de entrenamiento transcurrido fue 0.0 horas, 41.0 minutos, 33.05 segundos)
# Modelo inception_retina_v1_40_learn_4.0_batch_16_rep_9 guardado con exito
#
#
# Testeando el modelo...
#
#
# 83/83 [==============================] - 5s 64ms/step - loss: 0.7323 - accuracy: 0.9373
#
#
# Validating...
#
#
# 26/26 [==============================] - 5s 166ms/step - loss: 0.7647 - accuracy: 0.9325
#
#
#
#
# Test Accuracy:	 0.9373493790626526
# Test Loss:    	 0.7322783470153809
# Val Accuracy: 	 0.9325301051139832
# Val Loss:     	 0.7647371292114258
# 06/09/2024 05:04:44
#
#
# ==================================================================

# %%
Solve(nombre = "inception_retina_v1_40", learning = 1e-4, batch = 16, rep = 10, recuperar = 0, epocas = 40)
# Out:
# 06/09/2024 05:04:44
# Learning rate: 0.0001    batch size: 16    rep: 10
#
#
# No existe previamente el archivo temporal /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_10.h5
#  Epoch     Loss   Accuracy  V_loss    V_acc     LR     Next LR  Monitor  % Improv  Duration
#  1 /40     7.999   76.951   7.65245  84.819   0.00010  0.00010  accuracy     0.00    70.37
#
# Epoch 1: val_loss improved from inf to 7.65245, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_10.h5
#  2 /40     6.801   85.929   6.52236  90.361   0.00010  0.00010  accuracy    11.67    43.18
#
# Epoch 2: val_loss improved from 7.65245 to 6.52236, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_10.h5
#  3 /40     6.098   88.912   5.85791  89.639   0.00010  0.00010  accuracy     3.47    43.23
#
# Epoch 3: val_loss improved from 6.52236 to 5.85791, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_10.h5
#  4 /40     5.531   91.473   5.34319  90.843   0.00010  0.00010  val_loss     8.79    42.85
#
# Epoch 4: val_loss improved from 5.85791 to 5.34319, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_10.h5
#  5 /40     5.068   92.227   4.93848  90.361   0.00010  0.00010  val_loss     7.57    43.56
#
# Epoch 5: val_loss improved from 5.34319 to 4.93848, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_10.h5
#  6 /40     4.696   92.468   4.72942  87.952   0.00010  0.00010  val_loss     4.23    46.40
#
# Epoch 6: val_loss improved from 4.93848 to 4.72942, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_10.h5
#  7 /40     4.382   94.064   4.36838  88.916   0.00010  0.00010  val_loss     7.63    43.47
#
# Epoch 7: val_loss improved from 4.72942 to 4.36838, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_10.h5
#  8 /40     4.103   95.059   4.42467  85.301   0.00010  0.00005  val_loss    -1.29    43.31
#
# Epoch 8: val_loss did not improve from 4.36838
#  9 /40     3.897   95.782   3.93914  92.048   0.00005  0.00005  val_loss     9.83    43.71
#
# Epoch 9: val_loss improved from 4.36838 to 3.93914, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_10.h5
# 10 /40     3.765   97.198   3.91960  89.639   0.00005  0.00005  val_loss     0.50    45.24
#
# Epoch 10: val_loss improved from 3.93914 to 3.91960, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_10.h5
# 11 /40     3.642   96.927   4.63815  85.783   0.00005  0.00002  val_loss    -18.33   42.97
#
# Epoch 11: val_loss did not improve from 3.91960
# 12 /40     3.528   97.801   3.74960  88.434   0.00002  0.00002  val_loss     4.34    43.26
#
# Epoch 12: val_loss improved from 3.91960 to 3.74960, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_10.h5
# 13 /40     3.463   97.801   3.64615  88.916   0.00002  0.00002  val_loss     2.76    45.40
#
# Epoch 13: val_loss improved from 3.74960 to 3.64615, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.0001/temp_inception_retina_v1_40_learn_4.0_batch_16_rep_10.h5
# 14 /40     3.396   98.252   3.67628  89.157   0.00002  0.00001  val_loss    -0.83    43.61
#
# Epoch 14: val_loss did not improve from 3.64615
# 15 /40     3.341   98.494   3.77088  88.434   0.00001  0.00001  val_loss    -3.42    42.57
#
# Epoch 15: val_loss did not improve from 3.64615
# 16 /40     3.315   98.433   3.92093  86.747   0.00001  0.00000  val_loss    -7.54    44.34
# El entrenamiento se ha detenido en el epoch 16 después de 3 ajustes de la tasa de aprendizaje sin ninguna mejora.
#
# Epoch 16: val_loss did not improve from 3.64615
# el tiempo de entrenamiento transcurrido fue 0.0 horas, 16.0 minutos, 43.40 segundos)
# Modelo inception_retina_v1_40_learn_4.0_batch_16_rep_10 guardado con exito
#
#
# Testeando el modelo...
#
#
# 83/83 [==============================] - 4s 53ms/step - loss: 3.5826 - accuracy: 0.9157
#
#
# Validating...
#
#
# 26/26 [==============================] - 6s 235ms/step - loss: 3.6462 - accuracy: 0.8892
#
#
#
#
# Test Accuracy:	 0.9156626462936401
# Test Loss:    	 3.5825815200805664
# Val Accuracy: 	 0.8891566395759583
# Val Loss:     	 3.646151065826416
# 06/09/2024 05:21:45
#
#
# ==================================================================

# %%
Solve(nombre = "inception_retina_v1_40", learning = 1e-3, batch = 16, rep = 6, recuperar = 0, epocas = 40)
# Out:
# 07/09/2024 21:32:28
# Learning rate: 0.001    batch size: 16    rep: 6
#
#
# No existe previamente el archivo temporal /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_6.h5
#  Epoch     Loss   Accuracy  V_loss    V_acc     LR     Next LR  Monitor  % Improv  Duration
#  1 /40     5.647   85.658   5.21803  82.651   0.00100  0.00100  accuracy     0.00   1439.12
#
# Epoch 1: val_loss improved from inf to 5.21803, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_6.h5
#  2 /40     3.458   90.931   5.14612  83.133   0.00100  0.00100  val_loss     1.38    49.24
#
# Epoch 2: val_loss improved from 5.21803 to 5.14612, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_6.h5
#  3 /40     2.494   91.714   4.02069  84.337   0.00100  0.00100  val_loss    21.87    50.79
#
# Epoch 3: val_loss improved from 5.14612 to 4.02069, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_6.h5
#  4 /40     1.824   93.522   1.68357  92.048   0.00100  0.00100  val_loss    58.13    48.26
#
# Epoch 4: val_loss improved from 4.02069 to 1.68357, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_6.h5
#  5 /40     1.358   94.516   1.19716  93.012   0.00100  0.00100  val_loss    28.89    51.18
#
# Epoch 5: val_loss improved from 1.68357 to 1.19716, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_6.h5
#  6 /40     1.033   94.697   0.97032  93.012   0.00100  0.00100  val_loss    18.95    48.83
#
# Epoch 6: val_loss improved from 1.19716 to 0.97032, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_6.h5
#  7 /40     0.765   95.390   0.70795  93.253   0.00100  0.00100  val_loss    27.04    51.32
#
# Epoch 7: val_loss improved from 0.97032 to 0.70795, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_6.h5
#  8 /40     0.595   95.420   0.57733  92.771   0.00100  0.00100  val_loss    18.45    50.42
#
# Epoch 8: val_loss improved from 0.70795 to 0.57733, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_6.h5
#  9 /40     0.536   95.059   0.68592  93.735   0.00100  0.00050  val_loss    -18.81   47.94
#
# Epoch 9: val_loss did not improve from 0.57733
# 10 /40     0.389   98.102   0.47611  94.217   0.00050  0.00050  val_loss    17.53    50.49
#
# Epoch 10: val_loss improved from 0.57733 to 0.47611, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_6.h5
# 11 /40     0.356   98.011   0.45033  93.976   0.00050  0.00050  val_loss     5.41    48.71
#
# Epoch 11: val_loss improved from 0.47611 to 0.45033, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_6.h5
# 12 /40     0.323   98.433   0.46001  92.771   0.00050  0.00025  val_loss    -2.15    47.87
#
# Epoch 12: val_loss did not improve from 0.45033
# 13 /40     0.281   98.945   0.41312  94.458   0.00025  0.00025  val_loss     8.26    49.58
#
# Epoch 13: val_loss improved from 0.45033 to 0.41312, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_6.h5
# 14 /40     0.261   99.217   0.37153  94.940   0.00025  0.00025  val_loss    10.07    49.56
#
# Epoch 14: val_loss improved from 0.41312 to 0.37153, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_6.h5
# 15 /40     0.248   99.307   0.36944  95.181   0.00025  0.00025  val_loss     0.56    50.30
#
# Epoch 15: val_loss improved from 0.37153 to 0.36944, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_6.h5
# 16 /40     0.225   99.548   0.37973  94.699   0.00025  0.00013  val_loss    -2.79    54.21
#
# Epoch 16: val_loss did not improve from 0.36944
# 17 /40     0.212   99.608   0.33765  94.940   0.00013  0.00013  val_loss     8.61    47.97
#
# Epoch 17: val_loss improved from 0.36944 to 0.33765, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_6.h5
# 18 /40     0.206   99.669   0.34713  94.217   0.00013  0.00006  val_loss    -2.81    49.44
#
# Epoch 18: val_loss did not improve from 0.33765
# 19 /40     0.192   99.910   0.38682  94.458   0.00006  0.00003  val_loss    -14.56   48.39
#
# Epoch 19: val_loss did not improve from 0.33765
# 20 /40     0.189   99.940   0.34593  94.699   0.00003  0.00002  val_loss    -2.45    49.58
# El entrenamiento se ha detenido en el epoch 20 después de 3 ajustes de la tasa de aprendizaje sin ninguna mejora.
#
# Epoch 20: val_loss did not improve from 0.33765
# el tiempo de entrenamiento transcurrido fue 0.0 horas, 45.0 minutos, 53.38 segundos)
# Modelo inception_retina_v1_40_learn_3.0_batch_16_rep_6 guardado con exito
#
#
# Testeando el modelo...
#
#
# 83/83 [==============================] - 154s 2s/step - loss: 0.3497 - accuracy: 0.9470
#
#
# Validating...
#
#
# 26/26 [==============================] - 5s 177ms/step - loss: 0.3377 - accuracy: 0.9494
#
#
#
#
# Test Accuracy:	 0.9469879269599915
# Test Loss:    	 0.3496750295162201
# Val Accuracy: 	 0.9493975639343262
# Val Loss:     	 0.3376506268978119
# 07/09/2024 22:21:59
#
#
# ==================================================================

# %%
Solve(nombre = "inception_retina_v1_40", learning = 1e-3, batch = 16, rep = 7, recuperar = 0, epocas = 40)
# Out:
# 09/09/2024 21:16:52
# Learning rate: 0.001    batch size: 16    rep: 7
#
#
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 1s 0us/step
# No existe previamente el archivo temporal /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_7.h5
#  Epoch     Loss   Accuracy  V_loss    V_acc     LR     Next LR  Monitor  % Improv  Duration
#  1 /40     6.061   83.971   4.68993  78.313   0.00100  0.00100  accuracy     0.00    964.68
#
# Epoch 1: val_loss improved from inf to 4.68993, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_7.h5
#  2 /40     3.558   91.232   2.90975  90.602   0.00100  0.00100  val_loss    37.96    47.90
#
# Epoch 2: val_loss improved from 4.68993 to 2.90975, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_7.h5
#  3 /40     2.381   92.528   1.95380  91.325   0.00100  0.00100  val_loss    32.85    46.45
#
# Epoch 3: val_loss improved from 2.90975 to 1.95380, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_7.h5
#  4 /40     1.602   93.341   1.32381  92.289   0.00100  0.00100  val_loss    32.24    46.08
#
# Epoch 4: val_loss improved from 1.95380 to 1.32381, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_7.h5
#  5 /40     1.104   93.462   1.09528  86.506   0.00100  0.00100  val_loss    17.26    47.49
#
# Epoch 5: val_loss improved from 1.32381 to 1.09528, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_7.h5
#  6 /40     0.784   94.306   0.71751  93.494   0.00100  0.00100  val_loss    34.49    47.46
#
# Epoch 6: val_loss improved from 1.09528 to 0.71751, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_7.h5
#  7 /40     0.588   94.486   0.57191  92.530   0.00100  0.00100  val_loss    20.29    46.56
#
# Epoch 7: val_loss improved from 0.71751 to 0.57191, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_7.h5
#  8 /40     0.456   95.149   0.48662  94.217   0.00100  0.00100  val_loss    14.91    49.65
#
# Epoch 8: val_loss improved from 0.57191 to 0.48662, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_7.h5
#  9 /40     0.369   96.053   0.40861  92.530   0.00100  0.00100  val_loss    16.03    46.86
#
# Epoch 9: val_loss improved from 0.48662 to 0.40861, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_7.h5
# 10 /40     0.336   95.270   0.38839  92.530   0.00100  0.00100  val_loss     4.95    49.05
#
# Epoch 10: val_loss improved from 0.40861 to 0.38839, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_7.h5
# 11 /40     0.286   95.993   0.40817  92.771   0.00100  0.00050  val_loss    -5.09    47.27
#
# Epoch 11: val_loss did not improve from 0.38839
# 12 /40     0.219   97.951   0.36236  91.325   0.00050  0.00050  val_loss     6.70    48.16
#
# Epoch 12: val_loss improved from 0.38839 to 0.36236, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_7.h5
# 13 /40     0.204   98.192   0.30131  94.940   0.00050  0.00050  val_loss    16.85    48.79
#
# Epoch 13: val_loss improved from 0.36236 to 0.30131, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_7.h5
# 14 /40     0.182   98.463   0.30099  92.289   0.00050  0.00050  val_loss     0.11    47.12
#
# Epoch 14: val_loss improved from 0.30131 to 0.30099, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_7.h5
# 15 /40     0.177   98.222   0.29783  93.976   0.00050  0.00050  val_loss     1.05    48.05
#
# Epoch 15: val_loss improved from 0.30099 to 0.29783, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_7.h5
# 16 /40     0.160   98.855   0.36529  92.289   0.00050  0.00025  val_loss    -22.65   54.64
#
# Epoch 16: val_loss did not improve from 0.29783
# 17 /40     0.142   99.096   0.34405  92.771   0.00025  0.00013  val_loss    -15.52   48.18
#
# Epoch 17: val_loss did not improve from 0.29783
# 18 /40     0.130   99.548   0.27629  93.735   0.00013  0.00013  val_loss     7.23    48.62
#
# Epoch 18: val_loss improved from 0.29783 to 0.27629, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_7.h5
# 19 /40     0.129   99.518   0.29897  93.012   0.00013  0.00006  val_loss    -8.21    50.07
#
# Epoch 19: val_loss did not improve from 0.27629
# 20 /40     0.127   99.548   0.29760  93.012   0.00006  0.00003  val_loss    -7.71    47.87
#
# Epoch 20: val_loss did not improve from 0.27629
# 21 /40     0.121   99.759   0.29573  93.253   0.00003  0.00002  val_loss    -7.03    48.20
# El entrenamiento se ha detenido en el epoch 21 después de 3 ajustes de la tasa de aprendizaje sin ninguna mejora.
#
# Epoch 21: val_loss did not improve from 0.27629
# el tiempo de entrenamiento transcurrido fue 0.0 horas, 36.0 minutos, 20.66 segundos)
# Modelo inception_retina_v1_40_learn_3.0_batch_16_rep_7 guardado con exito
#
#
# Testeando el modelo...
#
#
# 83/83 [==============================] - 90s 1s/step - loss: 0.3033 - accuracy: 0.9301
#
#
# Validating...
#
#
# 26/26 [==============================] - 5s 174ms/step - loss: 0.2763 - accuracy: 0.9373
#
#
#
#
# Test Accuracy:	 0.9301204681396484
# Test Loss:    	 0.3032941222190857
# Val Accuracy: 	 0.9373493790626526
# Val Loss:     	 0.27629220485687256
# 09/09/2024 21:55:50
#
#
# ==================================================================

# %%
Solve(nombre = "inception_retina_v1_40", learning = 1e-3, batch = 16, rep = 8, recuperar = 0, epocas = 40)
# Out:
# 09/09/2024 21:55:50
# Learning rate: 0.001    batch size: 16    rep: 8
#
#
# No existe previamente el archivo temporal /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_8.h5
#  Epoch     Loss   Accuracy  V_loss    V_acc     LR     Next LR  Monitor  % Improv  Duration
#  1 /40     6.041   83.338   4.55472  88.675   0.00100  0.00100  accuracy     0.00    76.40
#
# Epoch 1: val_loss improved from inf to 4.55472, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_8.h5
#  2 /40     3.615   89.997   3.03467  83.133   0.00100  0.00100  accuracy     7.99    50.45
#
# Epoch 2: val_loss improved from 4.55472 to 3.03467, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_8.h5
#  3 /40     2.514   91.052   2.22391  88.434   0.00100  0.00100  val_loss    26.72    46.33
#
# Epoch 3: val_loss improved from 3.03467 to 2.22391, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_8.h5
#  4 /40     1.807   92.588   1.58435  91.325   0.00100  0.00100  val_loss    28.76    46.23
#
# Epoch 4: val_loss improved from 2.22391 to 1.58435, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_8.h5
#  5 /40     1.351   93.402   1.23600  91.084   0.00100  0.00100  val_loss    21.99    45.90
#
# Epoch 5: val_loss improved from 1.58435 to 1.23600, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_8.h5
#  6 /40     1.036   94.064   0.96972  92.530   0.00100  0.00100  val_loss    21.54    46.67
#
# Epoch 6: val_loss improved from 1.23600 to 0.96972, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_8.h5
#  7 /40     0.793   94.938   0.81367  88.193   0.00100  0.00100  val_loss    16.09    47.80
#
# Epoch 7: val_loss improved from 0.96972 to 0.81367, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_8.h5
#  8 /40     0.624   94.908   0.77477  89.157   0.00100  0.00100  val_loss     4.78    46.25
#
# Epoch 8: val_loss improved from 0.81367 to 0.77477, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_8.h5
#  9 /40     0.501   95.993   0.55885  93.494   0.00100  0.00100  val_loss    27.87    45.66
#
# Epoch 9: val_loss improved from 0.77477 to 0.55885, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_8.h5
# 10 /40     0.418   95.812   0.49810  93.735   0.00100  0.00100  val_loss    10.87    45.25
#
# Epoch 10: val_loss improved from 0.55885 to 0.49810, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_8.h5
# 11 /40     0.369   95.661   0.45988  93.253   0.00100  0.00100  val_loss     7.67    47.84
#
# Epoch 11: val_loss improved from 0.49810 to 0.45988, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_8.h5
# 12 /40     0.305   96.354   0.33037  92.771   0.00100  0.00100  val_loss    28.16    47.20
#
# Epoch 12: val_loss improved from 0.45988 to 0.33037, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_8.h5
# 13 /40     0.306   95.842   0.56359  92.530   0.00100  0.00050  val_loss    -70.59   45.94
#
# Epoch 13: val_loss did not improve from 0.33037
# 14 /40     0.226   97.891   0.32085  93.253   0.00050  0.00050  val_loss     2.88    48.11
#
# Epoch 14: val_loss improved from 0.33037 to 0.32085, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_8.h5
# 15 /40     0.196   98.765   0.35984  93.253   0.00050  0.00025  val_loss    -12.15   47.31
#
# Epoch 15: val_loss did not improve from 0.32085
# 16 /40     0.187   98.644   0.31493  93.976   0.00025  0.00025  val_loss     1.84    47.46
#
# Epoch 16: val_loss improved from 0.32085 to 0.31493, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_8.h5
# 17 /40     0.170   99.156   0.34577  92.048   0.00025  0.00013  val_loss    -9.79    49.85
#
# Epoch 17: val_loss did not improve from 0.31493
# 18 /40     0.158   99.488   0.31929  93.494   0.00013  0.00006  val_loss    -1.39    46.70
#
# Epoch 18: val_loss did not improve from 0.31493
# 19 /40     0.156   99.458   0.29846  93.735   0.00006  0.00006  val_loss     5.23    47.42
#
# Epoch 19: val_loss improved from 0.31493 to 0.29846, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_8.h5
# 20 /40     0.149   99.789   0.29494  93.494   0.00006  0.00006  val_loss     1.18    51.76
#
# Epoch 20: val_loss improved from 0.29846 to 0.29494, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_8.h5
# 21 /40     0.145   99.849   0.32499  92.530   0.00006  0.00003  val_loss    -10.19   48.06
#
# Epoch 21: val_loss did not improve from 0.29494
# 22 /40     0.143   99.699   0.30828  92.530   0.00003  0.00002  val_loss    -4.53    47.95
#
# Epoch 22: val_loss did not improve from 0.29494
# 23 /40     0.140   99.819   0.30524  93.253   0.00002  0.00001  val_loss    -3.49    47.71
# El entrenamiento se ha detenido en el epoch 23 después de 3 ajustes de la tasa de aprendizaje sin ninguna mejora.
#
# Epoch 23: val_loss did not improve from 0.29494
# el tiempo de entrenamiento transcurrido fue 0.0 horas, 23.0 minutos, 28.90 segundos)
# Modelo inception_retina_v1_40_learn_3.0_batch_16_rep_8 guardado con exito
#
#
# Testeando el modelo...
#
#
# 83/83 [==============================] - 6s 73ms/step - loss: 0.2998 - accuracy: 0.9373
#
#
# Validating...
#
#
# 26/26 [==============================] - 5s 199ms/step - loss: 0.2949 - accuracy: 0.9349
#
#
#
#
# Test Accuracy:	 0.9373493790626526
# Test Loss:    	 0.29975420236587524
# Val Accuracy: 	 0.9349397420883179
# Val Loss:     	 0.2949366867542267
# 09/09/2024 22:20:21
#
#
# ==================================================================

# %%
Solve(nombre = "inception_retina_v1_40", learning = 1e-3, batch = 16, rep = 9, recuperar = 0, epocas = 40)
# Out:
# 09/09/2024 22:20:21
# Learning rate: 0.001    batch size: 16    rep: 9
#
#
# No existe previamente el archivo temporal /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_9.h5
#  Epoch     Loss   Accuracy  V_loss    V_acc     LR     Next LR  Monitor  % Improv  Duration
#  1 /40     6.120   81.470   7.34992  90.602   0.00100  0.00100  accuracy     0.00    78.72
#
# Epoch 1: val_loss improved from inf to 7.34992, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_9.h5
#  2 /40     3.893   90.539   3.42080  82.410   0.00100  0.00100  val_loss    53.46    47.12
#
# Epoch 2: val_loss improved from 7.34992 to 3.42080, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_9.h5
#  3 /40     2.776   91.473   2.44603  90.843   0.00100  0.00100  val_loss    28.50    47.45
#
# Epoch 3: val_loss improved from 3.42080 to 2.44603, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_9.h5
#  4 /40     2.017   92.588   1.78364  91.325   0.00100  0.00100  val_loss    27.08    49.60
#
# Epoch 4: val_loss improved from 2.44603 to 1.78364, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_9.h5
#  5 /40     1.444   94.366   1.23046  91.807   0.00100  0.00100  val_loss    31.01    46.81
#
# Epoch 5: val_loss improved from 1.78364 to 1.23046, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_9.h5
#  6 /40     1.053   93.793   0.97961  91.807   0.00100  0.00100  val_loss    20.39    47.40
#
# Epoch 6: val_loss improved from 1.23046 to 0.97961, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_9.h5
#  7 /40     0.758   94.818   0.83954  86.506   0.00100  0.00100  val_loss    14.30    47.11
#
# Epoch 7: val_loss improved from 0.97961 to 0.83954, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_9.h5
#  8 /40     0.568   95.029   0.63228  88.916   0.00100  0.00100  val_loss    24.69    46.27
#
# Epoch 8: val_loss improved from 0.83954 to 0.63228, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_9.h5
#  9 /40     0.443   95.782   0.68559  91.566   0.00100  0.00050  val_loss    -8.43    47.66
#
# Epoch 9: val_loss did not improve from 0.63228
# 10 /40     0.359   96.867   0.45606  91.807   0.00050  0.00050  val_loss    27.87    48.24
#
# Epoch 10: val_loss improved from 0.63228 to 0.45606, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_9.h5
# 11 /40     0.300   98.102   0.49171  91.566   0.00050  0.00025  val_loss    -7.82    45.47
#
# Epoch 11: val_loss did not improve from 0.45606
# 12 /40     0.252   99.066   0.41198  93.012   0.00025  0.00025  val_loss     9.67    47.94
#
# Epoch 12: val_loss improved from 0.45606 to 0.41198, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_9.h5
# 13 /40     0.239   99.096   0.44618  92.048   0.00025  0.00013  val_loss    -8.30    46.79
#
# Epoch 13: val_loss did not improve from 0.41198
# 14 /40     0.220   99.217   0.39844  92.771   0.00013  0.00013  val_loss     3.29    45.69
#
# Epoch 14: val_loss improved from 0.41198 to 0.39844, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_9.h5
# 15 /40     0.206   99.638   0.40830  92.048   0.00013  0.00006  val_loss    -2.47    47.15
#
# Epoch 15: val_loss did not improve from 0.39844
# 16 /40     0.196   99.789   0.42797  92.530   0.00006  0.00003  val_loss    -7.41    47.37
#
# Epoch 16: val_loss did not improve from 0.39844
# 17 /40     0.195   99.699   0.41423  92.530   0.00003  0.00002  val_loss    -3.96    46.76
# El entrenamiento se ha detenido en el epoch 17 después de 3 ajustes de la tasa de aprendizaje sin ninguna mejora.
#
# Epoch 17: val_loss did not improve from 0.39844
# el tiempo de entrenamiento transcurrido fue 0.0 horas, 16.0 minutos, 28.30 segundos)
# Modelo inception_retina_v1_40_learn_3.0_batch_16_rep_9 guardado con exito
#
#
# Testeando el modelo...
#
#
# 83/83 [==============================] - 5s 57ms/step - loss: 0.4532 - accuracy: 0.9060
#
#
# Validating...
#
#
# 26/26 [==============================] - 6s 246ms/step - loss: 0.3984 - accuracy: 0.9277
#
#
#
#
# Test Accuracy:	 0.9060240983963013
# Test Loss:    	 0.45318272709846497
# Val Accuracy: 	 0.9277108311653137
# Val Loss:     	 0.39844411611557007
# 09/09/2024 22:37:08
#
#
# ==================================================================

# %%
Solve(nombre = "inception_retina_v1_40", learning = 1e-3, batch = 16, rep = 10, recuperar = 0, epocas = 40)
# Out:
# 09/09/2024 22:37:08
# Learning rate: 0.001    batch size: 16    rep: 10
#
#
# No existe previamente el archivo temporal /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_10.h5
#  Epoch     Loss   Accuracy  V_loss    V_acc     LR     Next LR  Monitor  % Improv  Duration
#  1 /40     5.698   84.604   4.12965  91.566   0.00100  0.00100  accuracy     0.00    78.34
#
# Epoch 1: val_loss improved from inf to 4.12965, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_10.h5
#  2 /40     3.394   90.298   2.79486  87.952   0.00100  0.00100  val_loss    32.32    46.67
#
# Epoch 2: val_loss improved from 4.12965 to 2.79486, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_10.h5
#  3 /40     2.328   91.775   2.02740  93.012   0.00100  0.00100  val_loss    27.46    46.69
#
# Epoch 3: val_loss improved from 2.79486 to 2.02740, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_10.h5
#  4 /40     1.748   92.287   4.69295  93.012   0.00100  0.00050  val_loss   -131.48   49.17
#
# Epoch 4: val_loss did not improve from 2.02740
#  5 /40     1.363   93.944   1.32949  92.771   0.00050  0.00050  val_loss    34.42    45.68
#
# Epoch 5: val_loss improved from 2.02740 to 1.32949, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_10.h5
#  6 /40     1.220   93.763   3.80876  87.952   0.00050  0.00025  val_loss   -186.48   46.17
#
# Epoch 6: val_loss did not improve from 1.32949
#  7 /40     1.064   95.631   1.33594  90.602   0.00025  0.00013  val_loss    -0.48    47.19
#
# Epoch 7: val_loss did not improve from 1.32949
#  8 /40     0.996   96.384   1.18471  91.566   0.00013  0.00013  val_loss    10.89    46.59
#
# Epoch 8: val_loss improved from 1.32949 to 1.18471, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_10.h5
#  9 /40     0.946   96.867   1.29586  91.325   0.00013  0.00006  val_loss    -9.38    46.26
#
# Epoch 9: val_loss did not improve from 1.18471
# 10 /40     0.905   97.620   1.13343  92.771   0.00006  0.00006  val_loss     4.33    47.80
#
# Epoch 10: val_loss improved from 1.18471 to 1.13343, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_10.h5
# 11 /40     0.868   98.283   1.04272  93.012   0.00006  0.00006  val_loss     8.00    46.94
#
# Epoch 11: val_loss improved from 1.13343 to 1.04272, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.001/temp_inception_retina_v1_40_learn_3.0_batch_16_rep_10.h5
# 12 /40     0.837   98.433   1.07117  92.289   0.00006  0.00003  val_loss    -2.73    47.57
#
# Epoch 12: val_loss did not improve from 1.04272
# 13 /40     0.820   98.463   1.19520  91.084   0.00003  0.00002  val_loss    -14.62   47.76
#
# Epoch 13: val_loss did not improve from 1.04272
# 14 /40     0.803   98.825   1.15670  91.566   0.00002  0.00001  val_loss    -10.93   45.61
# El entrenamiento se ha detenido en el epoch 14 después de 3 ajustes de la tasa de aprendizaje sin ninguna mejora.
#
# Epoch 14: val_loss did not improve from 1.04272
# el tiempo de entrenamiento transcurrido fue 0.0 horas, 12.0 minutos, 48.06 segundos)
# Modelo inception_retina_v1_40_learn_3.0_batch_16_rep_10 guardado con exito
#
#
# Testeando el modelo...
#
#
# 83/83 [==============================] - 5s 64ms/step - loss: 1.0291 - accuracy: 0.9277
#
#
# Validating...
#
#
# 26/26 [==============================] - 6s 230ms/step - loss: 1.0427 - accuracy: 0.9301
#
#
#
#
# Test Accuracy:	 0.9277108311653137
# Test Loss:    	 1.0291426181793213
# Val Accuracy: 	 0.9301204681396484
# Val Loss:     	 1.0427156686782837
# 09/09/2024 22:50:18
#
#
# ==================================================================

# %%
Solve(nombre = "inception_retina_v1_40", learning = 1e-2, batch = 16, rep = 6, recuperar = 0, epocas = 40)
# Out:
# 09/09/2024 22:50:18
# Learning rate: 0.01    batch size: 16    rep: 6
#
#
# No existe previamente el archivo temporal /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_6.h5
#  Epoch     Loss   Accuracy  V_loss    V_acc     LR     Next LR  Monitor  % Improv  Duration
#  1 /40     5.145   69.780   9.83985  73.976   0.01000  0.01000  accuracy     0.00    78.74
#
# Epoch 1: val_loss improved from inf to 9.83985, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_6.h5
#  2 /40     0.861   73.998  38.18122  73.976   0.01000  0.01000  accuracy     6.04    46.75
#
# Epoch 2: val_loss did not improve from 9.83985
#  3 /40     0.623   74.028   5.55659  73.976   0.01000  0.01000  accuracy     0.04    47.49
#
# Epoch 3: val_loss improved from 9.83985 to 5.55659, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_6.h5
#  4 /40     0.607   74.119   1.02844  73.976   0.01000  0.01000  accuracy     0.12    47.69
#
# Epoch 4: val_loss improved from 5.55659 to 1.02844, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_6.h5
#  5 /40     0.623   73.998   1.60350  73.976   0.01000  0.00500  accuracy    -0.16    49.25
#
# Epoch 5: val_loss did not improve from 1.02844
#  6 /40     0.575   74.119   0.57214  73.976   0.00500  0.00250  accuracy     0.00    45.93
#
# Epoch 6: val_loss improved from 1.02844 to 0.57214, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_6.h5
#  7 /40     0.566   74.119   0.67441  73.976   0.00250  0.00125  accuracy     0.00    48.26
# El entrenamiento se ha detenido en el epoch 7 después de 3 ajustes de la tasa de aprendizaje sin ninguna mejora.
#
# Epoch 7: val_loss did not improve from 0.57214
# el tiempo de entrenamiento transcurrido fue 0.0 horas,  6.0 minutos, 44.64 segundos)
# Modelo inception_retina_v1_40_learn_2.0_batch_16_rep_6 guardado con exito
#
#
# Testeando el modelo...
#
#
# 83/83 [==============================] - 5s 56ms/step - loss: 0.9947 - accuracy: 0.7422
#
#
# Validating...
#
#
# 26/26 [==============================] - 6s 242ms/step - loss: 1.0284 - accuracy: 0.7398
#
#
#
#
# Test Accuracy:	 0.742168664932251
# Test Loss:    	 0.994654655456543
# Val Accuracy: 	 0.7397590279579163
# Val Loss:     	 1.0284359455108643
# 09/09/2024 22:57:21
#
#
# ==================================================================

# %%
Solve(nombre = "inception_retina_v1_40", learning = 1e-2, batch = 16, rep = 7, recuperar = 1, epocas = 40)
# Out:
# 11/09/2024 18:44:04
# Learning rate: 0.01    batch size: 16    rep: 7
#
#
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step
#  Epoch     Loss   Accuracy  V_loss    V_acc     LR     Next LR  Monitor  % Improv  Duration
#  1 /40     0.861   73.245   0.96225  72.289   0.01000  0.01000  accuracy     0.00   1267.01
#
# Epoch 1: val_loss improved from inf to 0.96225, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_7.h5
#  2 /40     0.602   73.998   0.61934  73.976   0.01000  0.01000  accuracy     1.03    52.75
#
# Epoch 2: val_loss improved from 0.96225 to 0.61934, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_7.h5
#  3 /40     0.591   74.089   0.61527  73.976   0.01000  0.01000  accuracy     0.12    48.04
#
# Epoch 3: val_loss improved from 0.61934 to 0.61527, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_7.h5
#  4 /40     0.589   74.119   0.59131  73.976   0.01000  0.01000  accuracy     0.04    48.75
#
# Epoch 4: val_loss improved from 0.61527 to 0.59131, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_7.h5
#  5 /40     0.596   74.089   0.59952  73.976   0.01000  0.00500  accuracy    -0.04    48.84
#
# Epoch 5: val_loss did not improve from 0.59131
#  6 /40     0.578   74.119   0.57867  73.976   0.00500  0.00250  accuracy     0.00    48.51
#
# Epoch 6: val_loss improved from 0.59131 to 0.57867, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_7.h5
#  7 /40     0.573   74.119   0.57458  73.976   0.00250  0.00125  accuracy     0.00    51.54
# El entrenamiento se ha detenido en el epoch 7 después de 3 ajustes de la tasa de aprendizaje sin ninguna mejora.
#
# Epoch 7: val_loss improved from 0.57867 to 0.57458, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_7.h5
# el tiempo de entrenamiento transcurrido fue 0.0 horas, 26.0 minutos, 51.33 segundos)
# Modelo inception_retina_v1_40_learn_2.0_batch_16_rep_7 guardado con exito
#
#
# Testeando el modelo...
#
#
# 83/83 [==============================] - 145s 2s/step - loss: 0.5843 - accuracy: 0.7422
#
#
# Validating...
#
#
# 26/26 [==============================] - 4s 169ms/step - loss: 0.5913 - accuracy: 0.7398
#
#
#
#
# Test Accuracy:	 0.742168664932251
# Test Loss:    	 0.5842911601066589
# Val Accuracy: 	 0.7397590279579163
# Val Loss:     	 0.5913055539131165
# 11/09/2024 19:14:42
#
#
# ==================================================================

# %%
Solve(nombre = "inception_retina_v1_40", learning = 1e-2, batch = 16, rep = 8, recuperar = 0, epocas = 40)
# Out:
# 09/09/2024 23:20:44
# Learning rate: 0.01    batch size: 16    rep: 8
#
#
# No existe previamente el archivo temporal /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_8.h5
#  Epoch     Loss   Accuracy  V_loss    V_acc     LR     Next LR  Monitor  % Improv  Duration
#  1 /40     5.167   69.780  41.67653  73.976   0.01000  0.01000  accuracy     0.00    77.96
#
# Epoch 1: val_loss improved from inf to 41.67653, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_8.h5
#  2 /40     0.819   74.089   2.19990  73.976   0.01000  0.01000  accuracy     6.17    46.63
#
# Epoch 2: val_loss improved from 41.67653 to 2.19990, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_8.h5
#  3 /40     0.622   74.089   0.99453  73.976   0.01000  0.00500  accuracy     0.00    46.20
#
# Epoch 3: val_loss improved from 2.19990 to 0.99453, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_8.h5
#  4 /40     0.588   74.089   0.59468  73.976   0.00500  0.00250  accuracy     0.00    50.58
#
# Epoch 4: val_loss improved from 0.99453 to 0.59468, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_8.h5
#  5 /40     0.576   74.119   0.69919  73.976   0.00250  0.00250  accuracy     0.04    46.52
#
# Epoch 5: val_loss did not improve from 0.59468
#  6 /40     0.577   74.119   0.63821  73.976   0.00250  0.00125  accuracy     0.00    47.39
#
# Epoch 6: val_loss did not improve from 0.59468
#  7 /40     0.577   74.119   0.58842  73.976   0.00125  0.00062  accuracy     0.00    48.33
#
# Epoch 7: val_loss improved from 0.59468 to 0.58842, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_8.h5
#  8 /40     0.573   74.119   0.57474  73.976   0.00062  0.00031  accuracy     0.00    46.55
# El entrenamiento se ha detenido en el epoch 8 después de 3 ajustes de la tasa de aprendizaje sin ninguna mejora.
#
# Epoch 8: val_loss improved from 0.58842 to 0.57474, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_8.h5
# el tiempo de entrenamiento transcurrido fue 0.0 horas,  6.0 minutos, 59.67 segundos)
# Modelo inception_retina_v1_40_learn_2.0_batch_16_rep_8 guardado con exito
#
#
# Testeando el modelo...
#
#
# 83/83 [==============================] - 5s 60ms/step - loss: 0.7284 - accuracy: 0.7422
#
#
# Validating...
#
#
# 26/26 [==============================] - 5s 191ms/step - loss: 0.6992 - accuracy: 0.7398
#
#
#
#
# Test Accuracy:	 0.742168664932251
# Test Loss:    	 0.7283517718315125
# Val Accuracy: 	 0.7397590279579163
# Val Loss:     	 0.6991859674453735
# 09/09/2024 23:28:03
#
#
# ==================================================================

# %%
Solve(nombre = "inception_retina_v1_40", learning = 1e-2, batch = 16, rep = 9, recuperar = 0, epocas = 40)
# Out:
# 11/09/2024 19:14:42
# Learning rate: 0.01    batch size: 16    rep: 9
#
#
# No existe previamente el archivo temporal /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_9.h5
#  Epoch     Loss   Accuracy  V_loss    V_acc     LR     Next LR  Monitor  % Improv  Duration
#  1 /40     4.701   69.449   2.60701  67.711   0.01000  0.01000  accuracy     0.00    75.80
#
# Epoch 1: val_loss improved from inf to 2.60701, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_9.h5
#  2 /40     0.824   74.119   0.92853  73.976   0.01000  0.01000  accuracy     6.72    47.99
#
# Epoch 2: val_loss improved from 2.60701 to 0.92853, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_9.h5
#  3 /40     0.632   74.058   0.63470  73.976   0.01000  0.00500  accuracy    -0.08    50.08
#
# Epoch 3: val_loss improved from 0.92853 to 0.63470, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_9.h5
#  4 /40     0.587   74.119   0.58828  73.976   0.00500  0.00250  accuracy     0.00    49.39
#
# Epoch 4: val_loss improved from 0.63470 to 0.58828, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_9.h5
#  5 /40     0.579   74.119   0.57631  73.976   0.00250  0.00125  accuracy     0.00    48.88
# El entrenamiento se ha detenido en el epoch 5 después de 3 ajustes de la tasa de aprendizaje sin ninguna mejora.
#
# Epoch 5: val_loss improved from 0.58828 to 0.57631, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_9.h5
# el tiempo de entrenamiento transcurrido fue 0.0 horas,  4.0 minutos, 42.13 segundos)
# Modelo inception_retina_v1_40_learn_2.0_batch_16_rep_9 guardado con exito
#
#
# Testeando el modelo...
#
#
# 83/83 [==============================] - 7s 82ms/step - loss: 1.1028 - accuracy: 0.7422
#
#
# Validating...
#
#
# 26/26 [==============================] - 5s 179ms/step - loss: 0.9285 - accuracy: 0.7398
#
#
#
#
# Test Accuracy:	 0.742168664932251
# Test Loss:    	 1.1028178930282593
# Val Accuracy: 	 0.7397590279579163
# Val Loss:     	 0.9285293817520142
# 11/09/2024 19:19:49
#
#
# ==================================================================

# %%
Solve(nombre = "inception_retina_v1_40", learning = 1e-2, batch = 16, rep = 10, recuperar = 0, epocas = 40)
# Out:
# 11/09/2024 19:19:49
# Learning rate: 0.01    batch size: 16    rep: 10
#
#
# No existe previamente el archivo temporal /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_10.h5
#  Epoch     Loss   Accuracy  V_loss    V_acc     LR     Next LR  Monitor  % Improv  Duration
#  1 /40     4.140   71.196  16.26912  73.976   0.01000  0.01000  accuracy     0.00    76.59
#
# Epoch 1: val_loss improved from inf to 16.26912, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_10.h5
#  2 /40     0.779   74.058   1.00460  73.976   0.01000  0.01000  accuracy     4.02    48.14
#
# Epoch 2: val_loss improved from 16.26912 to 1.00460, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_10.h5
#  3 /40     0.640   73.998   1.53679  73.976   0.01000  0.00500  accuracy    -0.08    49.91
#
# Epoch 3: val_loss did not improve from 1.00460
#  4 /40     0.610   74.058   0.59952  73.976   0.00500  0.00250  accuracy     0.00    47.49
#
# Epoch 4: val_loss improved from 1.00460 to 0.59952, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_10.h5
#  5 /40     0.583   74.058   0.58221  73.976   0.00250  0.00125  accuracy     0.00    48.52
# El entrenamiento se ha detenido en el epoch 5 después de 3 ajustes de la tasa de aprendizaje sin ninguna mejora.
#
# Epoch 5: val_loss improved from 0.59952 to 0.58221, saving model to /content/drive/MyDrive/modelcheckpoints dataset2 v1/inception/0.01/temp_inception_retina_v1_40_learn_2.0_batch_16_rep_10.h5
# el tiempo de entrenamiento transcurrido fue 0.0 horas,  5.0 minutos, 31.23 segundos)
# Modelo inception_retina_v1_40_learn_2.0_batch_16_rep_10 guardado con exito
#
#
# Testeando el modelo...
#
#
# 83/83 [==============================] - 5s 64ms/step - loss: 1.9441 - accuracy: 0.7422
#
#
# Validating...
#
#
# 26/26 [==============================] - 6s 222ms/step - loss: 1.0046 - accuracy: 0.7398
#
#
#
#
# Test Accuracy:	 0.742168664932251
# Test Loss:    	 1.9440875053405762
# Val Accuracy: 	 0.7397590279579163
# Val Loss:     	 1.0045969486236572
# 11/09/2024 19:25:39
#
#
# ==================================================================

# %%
#Obtener predicciones con el modelo ya entrenado
lr=best_model[0]
checkpoint_filepath=f'/content/drive/MyDrive/modelcheckpoints dataset2 v1/best_model_{lr}.h5'
model=keras.models.load_model(checkpoint_filepath)
preds = model.predict_generator(test_gen)
y_pred = np.argmax(preds, axis=1)
print(y_pred)

# %%
g_dict = test_gen.class_indices
classes = list(g_dict.keys())

# Matriz de confusion
cm = confusion_matrix(test_gen.classes, y_pred)
plot_confusion_matrix(cm= cm, classes= classes, title = 'Confusion Matrix')

# Reporte de clasificacion de las diferentes clases
print(classification_report(test_gen.classes, y_pred, target_names= classes))

# %% [markdown]
# **1. Introducción**
#
# **Objetivo**
#
# El objetivo de este informe es documentar el proceso y los resultados obtenidos en la clasificación de imágenes de ojos sanos y ojos enfermos utilizando la arquitectura Inception. Se busca evaluar la efectividad de tres diferentes learning rates (0.01, 0.001, 0.0001) en la precisión del modelo, con un batch size de 16 y repitiendo cada experimento cinco veces a lo largo de 40 épocas.
#
# **Arquitectura Utilizada**
#
# Inception, También conocida como GoogLeNet, se caracteriza por su módulo de Inception que ayuda a mejorar la eficiencia computacional. Utiliza varios filtros en cada capa y concatena sus resultados para mejorar la capacidad de representación.
#
# **Dataset Utilizado**
#
# El conjunto de datos utilizado en este estudio es "Clasificación de las enfermedades oculares" (Eyes Disease Classification), compilado por Guna Venkat Doddi y publicado en 2022. Este dataset incluye imágenes de retina normales, retinopatía diabética, cataratas y glaucoma, con aproximadamente 1,000 imágenes diagnósticas por cada clase. Las enfermedades oculares abarcan una variedad de afecciones que afectan la visión y la salud ocular. El objetivo principal de este conjunto de datos es entrenar modelos de aprendizaje profundo para identificar patrones específicos asociados con cada una de estas enfermedades oculares. En esta primera fase del estudio, se decidió clasificar las imágenes en dos categorías (sano y enfermo) en lugar de cuatro (glaucoma, catarata, retinopatía diabética y sano). Esta decisión se tomó para simplificar el problema inicial y evaluar la capacidad del modelo para distinguir entre ojos sanos y cualquier patología ocular, lo que sienta las bases para estudios posteriores más detallados que aborden la clasificación específica de cada enfermedad.
#
# **2. Metodología**
#
# **Preprocesamiento de las Imágenes**
#
# Las imágenes de retinoscopía utilizadas en este estudio se caracterizan por estar en formato .jpg o .jpeg; las imágenes de retinas normales, cataratas y glaucoma están en formato .jpg, mientras que las de retinopatía diabética están en formato .jpeg. Aunque el tamaño de estas imágenes no es relevante debido a la flexibilidad de las redes neuronales convolucionales, se realizaron los siguientes pasos de preprocesamiento para asegurar la calidad de los datos:
#
# *  Redimensionamiento: Las imágenes fueron redimensionadas a 224x224 píxeles para cumplir con los requisitos de entrada de la arquitectura ResNet50.
# *  Normalización: Las imágenes fueron normalizadas para tener valores de píxeles entre 0 y 1, lo que ayuda a acelerar el entrenamiento y mejorar la convergencia del modelo.
# *  Augmentación de Datos: Se aplicaron técnicas de augmentación de datos como rotaciones, traslaciones, y flips horizontales para aumentar la variabilidad del dataset y mejorar la robustez del modelo.
#
# **Hiperparámetros**
#
# Para el desarrollo del modelo, se utilizaron los siguientes hiperparámetros y configuraciones:
#
# *   Learning Rates: Se probaron tres tasas de aprendizaje diferentes: 0.01, 0.001 y 0.0001.
# *   Batch Size: El tamaño del lote se fijó en 16 para todas las pruebas.
# *   Número de Épocas: Cada modelo se entrenó durante 40 épocas.
# *   Repeticiones: Se fijaron 5 repeticiones para cada learning rate.
# *   Función de Pérdida: Se utilizó la función de pérdida de entropía cruzada (Cross-Entropy Loss) para la clasificación.
# *   Función de Activación: La función de activación en la capa de salida fue Softmax, adecuada para la clasificación multiclase.
# *   Optimización: Se utilizó el optimizador Adam, conocido por su eficiencia y adaptación del learning rate durante el entrenamiento.
# *   Validación Cruzada: Se implementó un enfoque de validación cruzada para evaluar el desempeño del modelo y reducir el riesgo de sobreajuste
#
# **Metodología de Prototipado Rápido (MPR)**
#
# Se adoptó la Metodología de Prototipado Rápido (MPR) debido a su enfoque iterativo y ágil, que permite adaptar el modelo a medida que surgen nuevas necesidades y se recopilan datos adicionales. Esta metodología fomenta el uso de herramientas visuales para garantizar un desarrollo eficiente y efectivo del artefacto.
#
# Durante el proceso de desarrollo, se integraron diferentes arquitecturas de aprendizaje profundo como VGG19, ResNet50, Xception, EfficientNet e InceptionV3 para el entrenamiento, validación y pruebas. La variación paramétrica de la tasa de aprendizaje (0.01, 0.001, 0.0001) y las métricas de precisión (accuracy) y pérdida de validación (val_loss) se utilizaron para evaluar el rendimiento del modelo.
#
# El proceso de MPR incluye diferentes tipos de ciclos iterativos:
#
# *  Ciclo 1: Evaluar los cinco modelos (VGG19, ResNet50, Xception, EfficientNet, InceptionV3) con un dataset de dos clases (sano y enfermo).
# *  Ciclo 2: Evaluar los tres mejores modelos del ciclo anterior con un dataset de cuatro clases (glaucoma, catarata, retinopatía diabética, sano).
# *  Ciclo 3: Escoger el mejor modelo basado en los resultados obtenidos en los ciclos anteriores.
#
# Este ejercicio se encuentra en el ciclo 1.
#
#
# **3. Análisis de Resultados**
#
# **Comparación entre Learning Rates**
#
# ***Tabla General: Mejor Repeticion por Learning Rate***
#
# |learning_rate|repeticion|mejor_val_accuracy|mejor_val_loss|
# |---|---|---|---|
# |0.01|1|0.74|0.6025|
# |0.001|2|0.935|0.3427|
# |0.0001|4|0.93|1.0045|
#
# ***Tabla Learning Rate 0.01***
#
# |repeticion|	max_val_accuracy|	epoch_max_val_accuracy|min_val_loss|	epoch_min_val_loss|
# |---|---|---|---|---|
# |1|0.7397590279579163|0|0.5884295105934143|5|
# |2|0.7397590279579163|0|0.5760899782180786|5|
# |3|0.7397590279579163|0|0.5808636546134949|4|
# |4|0.7397590279579163|0|0.5916837453842163|4|
# |5|0.742168664932251|5|0.5805520415306091|7|
#
# ***Tabla Learning Rate 0.001***
#
# |repeticion|	max_val_accuracy|	epoch_max_val_accuracy|	min_val_loss|	epoch_min_val_loss|
# |---|---|---|---|---|
# |1|0.9445782899856568|10|0.3538622260093689|13|
# |2|0.942168653011322|13|0.3427038490772247|18|
# |3|0.9373493790626526|16|0.3225665390491485|19|
# |4|0.942168653011322|12|0.3244993984699249|18|
# |5|0.9397590160369872|8|0.3632903695106506|15|
#
# ***Tabla Learning Rate 0.0001***
#
# |repeticion|	max_val_accuracy|	epoch_max_val_accuracy|	min_val_loss|	epoch_min_val_loss|
# |---|---|---|---|---|
# |1|0.9373493790626526|9|3.05396032333374|17|
# |2|0.9397590160369872|11|2.936216115951538|20|
# |3|0.9469879269599916|17|1.4579957723617554|28|
# |4|0.9445782899856568|8|1.0044898986816406|39|
# |5|0.9469879269599916|7|1.1129004955291748|39|
#
#
# **4. Ajustes y Paciencia del Modelo**
#
# En este estudio, se utilizó una configuración de paciencia (patience). La paciencia se refiere al número de épocas durante las cuales el modelo puede no mejorar antes de que se ajuste la tasa de aprendizaje. Si la precisión de validación no mejora después de un número determinado de épocas, la tasa de aprendizaje se reduce por un factor predeterminado.
#
# El ajuste de la tasa de aprendizaje y la implementación de paciencia ayudaron a prevenir el sobreajuste y a mantener la eficiencia del modelo. En algunos casos, el modelo no alcanzó las 40 épocas completas debido a esta configuración, lo que resultó en la finalización anticipada del entrenamiento cuando no se observó mejora significativa en la precisión de validación o la pérdida de validación. Esta técnica de ajuste dinámico es crucial para encontrar el balance óptimo entre la precisión del modelo y la eficiencia del entrenamiento.
#
# **5. Conclusiones**
#
# ***Conclusiones según Tablas Específicas***
#
# * **Learning Rate 0.01**: Este learning rate mostró una precisión máxima promedio alrededor del 73.98% al 74.22% y una pérdida de validación en el rango de 0.576 a 0.591. La variabilidad en las métricas es alta, con algunos modelos alcanzando mejores resultados en términos de precisión y pérdida, pero con una tendencia general hacia una menor estabilidad y precisión.
#
# * **Learning Rate 0.001**: Este learning rate resultó ser el más consistente en la mayoría de las métricas. Las precisiones máximas varían entre 93.73% y 96.87%, y las pérdidas de validación están en un rango más estrecho de 0.213 a 0.363. Esto sugiere que es el valor más confiable para la arquitectura Inception, ofreciendo un buen equilibrio entre precisión y pérdida de validación.
#
# * **Learning Rate 0.0001**: Aunque este learning rate también logró buenas precisiones, variando entre 93.73% y 97.11%, las pérdidas de validación fueron significativamente más altas, en el rango de 0.315 a 3.054. Esto indica que aunque se logran resultados de precisión competitivos, el aprendizaje puede ser menos eficiente en cuanto a la minimización de la pérdida.
#
# ***Conclusiones según la Tabla General***
#
# * **Learning Rate 0.0001**: La repetición 5 alcanzó una precisión de validación del 95.9% y una pérdida de validación de 0.3159. Aunque ofrece una alta precisión, la pérdida de validación sugiere una mayor dificultad para ajustar el modelo de manera eficiente en comparación con otros learning rates.
#
# * **Learning Rate 0.001**: La repetición 3 logró la mejor precisión de validación con un 96.87% y una pérdida de validación de 0.2126, lo que confirma la alta efectividad y estabilidad de este learning rate para la arquitectura Inception.
#
# * **Learning Rate 0.01**: La repetición 1 alcanzó una precisión de validación del 74.0% y una pérdida de validación de 0.3625. Aunque puede obtener resultados aceptables, su desempeño es menos estable en comparación con los otros learning rates, mostrando una menor eficacia general.
#
# ***Conclusión General***
#
# El learning rate de 0.001 se destacó como el más efectivo para la arquitectura Inception en términos de precisión y estabilidad. Este valor proporciona un equilibrio adecuado entre la rapidez de convergencia y la minimización de la pérdida, logrando altas precisiones con baja variabilidad y consistentemente buenos resultados en las métricas evaluadas.
#
# **6. Anexos**
#
# Se incluye en está sección el anexo a la carpeta de Inception, en dónde se encontrarán las tablas expuestas en este informe, así como información adicional: https://drive.google.com/drive/folders/1ae9D8S-pVrl5cxn0L7w61VEoyTSLxqXZ?usp=drive_link
